# %% [markdown]
# # Chapter 2 - Market Basket Analysis (Association Rule Mining)

# %% [markdown]
# Market basket analysis (MBA) is a technique used in data mining by retail companies to increase sales by better understanding customer buying patterns. It involves analyzing large datasets, such as customer purchase history, to uncover item groupings and products that are likely to be frequently purchased together.

# %%
#Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style
# %matplotlib inline
from mlxtend.frequent_patterns import apriori,association_rules
from collections import Counter
from IPython.display import Image

import warnings
warnings.filterwarnings("ignore")

# %%
#read csv data
df = pd.read_csv('data/data.csv',encoding= 'unicode_escape')

#view first 5 rows
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# ### Data Preparation

# %%
#null check
df.isnull().sum().sort_values(ascending=False)
# Out:
# CustomerID     135080
# Description      1454
# InvoiceNo           0
# StockCode           0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# Country             0
# dtype: int64

# %%
#Drop N/A
df1 = df.dropna()

df1.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  406829.000000  406829.000000  406829.000000
# mean       12.061303       3.460471   15287.690570
# std       248.693370      69.315162    1713.600303
# min    -80995.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13953.000000
# 50%         5.000000       1.950000   15152.000000
# 75%        12.000000       3.750000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
#selecting data where quantity > 0
df1 = df1[df1.Quantity > 0]

df1.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  397924.000000  397924.000000  397924.000000
# mean       13.021823       3.116174   15294.315171
# std       180.420210      22.096788    1713.169877
# min         1.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13969.000000
# 50%         6.000000       1.950000   15159.000000
# 75%        12.000000       3.750000   16795.000000
# max     80995.000000    8142.750000   18287.000000

# %% [markdown]
# ### Insights from the dataset

# %% [markdown]
# #### Customers Insights
#
# This segment will answer the questions like :
#
#     1.Who all are my loyal customers?
#     2.Which customers have ordered most frequently?
#     3.Which customers contribute the most to my revenue?

# %%
df1.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# Creating a new feature 'Amount' which is the product of Quantity and its Unit Price
df1['Amount'] = df1['Quantity'] * df1['UnitPrice']

df1.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Amount
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom   15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom   20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom   22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom   20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom   20.34

# %%
# Using groupby function to highlight the Customers with most no. of orders (invoices)
orders = df1.groupby(by=['CustomerID','Country'], as_index=False)['InvoiceNo'].count()

print('The TOP 5 loyal customers with most number of orders...')
orders.sort_values(by='InvoiceNo', ascending=False).head()
# Out:
# The TOP 5 loyal customers with most number of orders...
#       CustomerID         Country  InvoiceNo
# 4019     17841.0  United Kingdom       7847
# 1888     14911.0            EIRE       5677
# 1298     14096.0  United Kingdom       5111
# 334      12748.0  United Kingdom       4596
# 1670     14606.0  United Kingdom       2700

# %% [markdown]
# ### Number of Orders by Different Customers

# %%
# Creating a subplot of size 15x6
plt.subplots(figsize=(15,6))

# Using the style bmh for better visualization
plt.style.use('bmh')

# X axis will denote the customer ID, Y axis will denote the number of orders
plt.plot(orders.CustomerID, orders.InvoiceNo)

# Labelling the X axis
plt.xlabel('Customers ID')

# Labelling the Y axis
plt.ylabel('Number of Orders')

# Giving a suitable title to the plot
plt.title('Number of Orders by different Customers')

plt.show()

# %%
# Using groupby function to highlight the Customers with highest spent amount (invoices)
money_spent = df1.groupby(by=['CustomerID','Country'], as_index=False)['Amount'].sum()

print('The TOP 5 profitable customers with highest money spent...')
money_spent.sort_values(by='Amount', ascending=False).head()
# Out:
# The TOP 5 profitable customers with highest money spent...
#       CustomerID         Country     Amount
# 1698     14646.0     Netherlands  280206.02
# 4210     18102.0  United Kingdom  259657.30
# 3737     17450.0  United Kingdom  194550.79
# 3017     16446.0  United Kingdom  168472.50
# 1888     14911.0            EIRE  143825.06

# %% [markdown]
# ### Money Spent by Different Customers

# %%
# Creating a subplot of size 15*6
plt.subplots(figsize=(15,6))

# X axis will denote the customer ID, Y axis will denote the amount spent
plt.plot(money_spent.CustomerID, money_spent.Amount)

# Using bmh style for better visualization
plt.style.use('bmh')

# Labelling the X-axis
plt.xlabel('Customers ID')

# Labelling the Y-axis
plt.ylabel('Money spent')

# Giving a suitable title to the plot
plt.title('Money Spent by different Customers')

plt.show()

# %% [markdown]
# ### Patterns based on DateTime
# This segment will answer the questions like:
#
#     1.In which month, the number of orders placed is the highest?
#     2.On which Day of a week, the number of orders placed is the highest?
#     3.At what time of the day, the store is the busiest?

# %%
df1.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Amount
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom   15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom   20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom   22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom   20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom   20.34

# %%
import datetime

# Convert InvoiceDate from object to datetime
df1['InvoiceDate'] = pd.to_datetime(df1.InvoiceDate, format='%m/%d/%Y %H:%M')

# Creating a new feature called year_month, such that December 2010 will be denoted as 201012
df1.insert(loc=2, column='year_month', value=df1['InvoiceDate'].map(lambda x: 100*x.year + x.month))

# Creating a new feature for Month
df1.insert(loc=3, column='month', value=df1.InvoiceDate.dt.month)

# Creating a new feature for Day
# +1 to make Monday=1.....until Sunday=7
df1.insert(loc=4, column='day', value=(df1.InvoiceDate.dt.dayofweek)+1)

# Creating a new feature for Hour
df1.insert(loc=5, column='hour', value=df1.InvoiceDate.dt.hour)

df1.head()
# Out:
#   InvoiceNo StockCode  year_month  month  day  hour  \
# 0    536365    85123A      201012     12    3     8
# 1    536365     71053      201012     12    3     8
# 2    536365    84406B      201012     12    3     8
# 3    536365    84029G      201012     12    3     8
# 4    536365    84029E      201012     12    3     8
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  Amount
# 0       2.55     17850.0  United Kingdom   15.30
# 1       3.39     17850.0  United Kingdom   20.34
# 2       2.75     17850.0  United Kingdom   22.00
# 3       3.39     17850.0  United Kingdom   20.34
# 4       3.39     17850.0  United Kingdom   20.34

# %% [markdown]
# ### How many orders are placed per month?

# %%
# Using bmh style for better visualization
plt.style.use('bmh')

# Using groupby to extract No. of Invoices year-monthwise
ax = df1.groupby('InvoiceNo')['year_month'].unique().value_counts().sort_index().plot(kind='bar',figsize=(15,6))

# Labelling the X axis
ax.set_xlabel('Month',fontsize=15)

# Labelling the Y-axis
ax.set_ylabel('Number of Orders',fontsize=15)

# Giving suitable title to the plot
ax.set_title('Number of orders for different Months (Dec 2010 - Dec 2011)',fontsize=15)

# Providing with X tick labels
ax.set_xticklabels(('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','Jun_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11','Dec_11'), 
                   rotation='horizontal', fontsize=13)

plt.show()

# %% [markdown]
# ### How many orders are placed per Day?

# %%
# Day = 6 is Saturday and there are no orders placed on Saturdays
df1[df1['day']==6]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, year_month, month, day, hour, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, Amount]
# Index: []

# %%
# Using groupby to count no. of Invoices daywise
ax = df1.groupby('InvoiceNo')['day'].unique().value_counts().sort_index().plot(kind='bar',figsize=(15,6))

# Labelling X axis
ax.set_xlabel('Day',fontsize=15)

# Labelling Y axis
ax.set_ylabel('Number of Orders',fontsize=15)

# Giving suitable title to the plot
ax.set_title('Number of orders for different Days',fontsize=15)

# Providing with X tick labels
# Since there are no orders placed on Saturdays, we are excluding Sat from xticklabels
ax.set_xticklabels(('Mon','Tue','Wed','Thur','Fri','Sun'), rotation='horizontal', fontsize=15)

plt.show()

# %% [markdown]
# ### How many orders are placed per Hour?

# %%
# Using groupby to get unique hours for each invoice, then explode to individual hours
hours = df1.groupby('InvoiceNo')['hour'].unique().explode()

# Count the number of occurrences of each hour
hour_counts = hours.value_counts().sort_index()

# Plot the results
ax = hour_counts.plot(kind='bar', figsize=(15, 6))

# Labeling X axis
ax.set_xlabel('Hour', fontsize=15)

# Labeling Y axis
ax.set_ylabel('Number of Orders', fontsize=15)

# Giving a suitable title to the plot
ax.set_title('Number of Orders for Different Hours', fontsize=15)

# Providing with X tick labels (all orders are placed between 6 and 20 hour)
ax.set_xticklabels(range(6, 21), rotation='horizontal', fontsize=15)

plt.show()

# %% [markdown]
# ### Free Items and Sales

# %% [markdown]
# This segment will display how FREE items impact the No. of Orders. This answers how will the discounts and offers impact my sale?

# %%
df1.UnitPrice.describe()
# Out:
# count    397924.000000
# mean          3.116174
# std          22.096788
# min           0.000000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max        8142.750000
# Name: UnitPrice, dtype: float64

# %% [markdown]
# Since the minimum unit price = 0, there are either incorrect entries or free items.

# %%
# checking the distribution of unit price
plt.subplots(figsize=(12,6))

# Using darkgrid style for better visualization
sns.set_style('darkgrid')

# Applying boxplot visualization on Unit Price
sns.boxplot(df1.UnitPrice)

plt.show()

# %% [markdown]
# Let's improve it!

# %%
# checking the distribution of unit price
plt.subplots(figsize=(12,6))

# Using darkgrid style for better visualization
sns.set_style('darkgrid')

# Applying boxplot visualization on Unit Price
box = plt.boxplot(df1['UnitPrice'], patch_artist=True)

# Adding colors and legend
colors = ['#1f77b4']  # You can choose any color you like
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# Adding a legend
plt.legend([box["boxes"][0]], ['Unit Price Distribution'], loc='upper right')

# Adding labels and title
plt.xlabel('Unit Price')
plt.ylabel('Values')
plt.title('Distribution of Unit Price')

# Display the plot
plt.show()

# %% [markdown]
# Items with UnitPrice = 0 are not outliers. These are the “free” items.

# %%
# Creating a new df of free items
free_items = df1[df1['UnitPrice'] == 0]
free_items.head()
# Out:
#       InvoiceNo StockCode  year_month  month  day  hour  \
# 9302     537197     22841      201012     12    7    14
# 33576    539263     22580      201012     12    4    14
# 40089    539722     22423      201012     12    2    13
# 47068    540372     22090      201101      1    4    16
# 47070    540372     22553      201101      1    4    16
#
#                         Description  Quantity         InvoiceDate  UnitPrice  \
# 9302   ROUND CAKE TIN VINTAGE GREEN         1 2010-12-05 14:02:00        0.0
# 33576  ADVENT CALENDAR GINGHAM SACK         4 2010-12-16 14:36:00        0.0
# 40089      REGENCY CAKESTAND 3 TIER        10 2010-12-21 13:45:00        0.0
# 47068       PAPER BUNTING RETROSPOT        24 2011-01-06 16:41:00        0.0
# 47070        PLASTERS IN TIN SKULLS        24 2011-01-06 16:41:00        0.0
#
#        CustomerID         Country  Amount
# 9302      12647.0         Germany     0.0
# 33576     16560.0  United Kingdom     0.0
# 40089     14911.0            EIRE     0.0
# 47068     13081.0  United Kingdom     0.0
# 47070     13081.0  United Kingdom     0.0

# %%
# Counting how many free items were given out year-month wise
free_items.year_month.value_counts().sort_index()
# Out:
# year_month
# 201012     3
# 201101     3
# 201102     1
# 201103     2
# 201104     2
# 201105     2
# 201107     2
# 201108     6
# 201109     2
# 201110     3
# 201111    14
# Name: count, dtype: int64

# %%
# Counting how many free items were given out year-month wise
ax = free_items.year_month.value_counts().sort_index().plot(kind='bar',figsize=(12,6))

# Labelling X-axis
ax.set_xlabel('Month',fontsize=15)

# Labelling Y-axis
ax.set_ylabel('Frequency',fontsize=15)

# Giving suitable title to the plot
ax.set_title('Frequency for different Months (Dec 2010 - Dec 2011)',fontsize=15)

# Providing X tick labels
# Since there are 0 free items in June 2011, we are excluding it
ax.set_xticklabels(('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11'), rotation='horizontal', 
                   fontsize=13)
plt.show()

# %% [markdown]
# The most no. of free items were given out in November 2011. Also, the most no. of orders were placed in November 2011 as seen below :

# %%
plt.style.use('bmh')

# Using groupby to count unique no. of Invoices year-month wise
ax = df1.groupby('InvoiceNo')['year_month'].unique().value_counts().sort_index().plot(kind='bar',figsize=(15,6))

# Labelling X axis
ax.set_xlabel('Month',fontsize=15)

# Labelling Y axis
ax.set_ylabel('Number of Orders',fontsize=15)

# Giving suitable title to the plot
ax.set_title('Number of orders for different Months (Dec 2010 - Dec 2011)',fontsize=15)

# Providing with X tick labels
ax.set_xticklabels(('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','Jun_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11','Dec_11'), 
                   rotation='horizontal', fontsize=13)

plt.show()

# %% [markdown]
# Also, compared to May, sales declined which means there was a slight effect of NO FREE ITEMS on the number of orders.

# %%
plt.style.use('bmh')

# Using groupby to sum the amount spent year-month wise
ax = df1.groupby('year_month')['Amount'].sum().sort_index().plot(kind='bar',figsize=(15,6))

# Labelling X axis
ax.set_xlabel('Month',fontsize=15)

# Labelling Y axis
ax.set_ylabel('Amount',fontsize=15)

# Giving suitable title to the plot
ax.set_title('Revenue Generated for different Months (Dec 2010 - Dec 2011)',fontsize=15)

# Providing with X tick labels
ax.set_xticklabels(('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','Jun_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11','Dec_11'), 
                   rotation='horizontal', fontsize=13)

plt.show()

# %% [markdown]
# ### Items Insights
# This segment will answer the questions like :
#
#     1.Which item is bought by most no. of customers?
#     2.Which is the most sold item based on sum of sales?
#     3.Which is the most sold item based on the count of orders?
#     4.Which items are the first choice items for most no. of invoices?

# %% [markdown]
# ### Most sold item based on Quantity

# %%
df1.head()
# Out:
#   InvoiceNo StockCode  year_month  month  day  hour  \
# 0    536365    85123A      201012     12    3     8
# 1    536365     71053      201012     12    3     8
# 2    536365    84406B      201012     12    3     8
# 3    536365    84029G      201012     12    3     8
# 4    536365    84029E      201012     12    3     8
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  Amount
# 0       2.55     17850.0  United Kingdom   15.30
# 1       3.39     17850.0  United Kingdom   20.34
# 2       2.75     17850.0  United Kingdom   22.00
# 3       3.39     17850.0  United Kingdom   20.34
# 4       3.39     17850.0  United Kingdom   20.34

# %%
# Creating a new pivot table which sums the Quantity ordered for each item
most_sold_items = df1.pivot_table(index=['StockCode','Description'], values='Quantity', aggfunc='sum').sort_values(by='Quantity', ascending=False)

most_sold_items.head()
# Out:
#                                               Quantity
# StockCode Description
# 23843     PAPER CRAFT , LITTLE BIRDIE            80995
# 23166     MEDIUM CERAMIC TOP STORAGE JAR         77916
# 84077     WORLD WAR 2 GLIDERS ASSTD DESIGNS      54415
# 85099B    JUMBO BAG RED RETROSPOT                46181
# 85123A    WHITE HANGING HEART T-LIGHT HOLDER     36725

# %%
most_sold_items.reset_index(inplace=True)
sns.set_style('white')

# Creating a bar plot of Description ( or the item ) on the Y axis and the sum of Quantity on the X axis
# We are plotting only the 10 most ordered items
sns.barplot(y='Description', x='Quantity', data=most_sold_items.head(10))

# Giving suitable title to the plot
plt.title('Top 10 Items based on No. of Sales', fontsize=14)

plt.ylabel('Item')
# Out:
# Text(0, 0.5, 'Item')

# %% [markdown]
# ### Items bought by most no. of Customers

# %%
# choosing WHITE HANGING HEART T-LIGHT HOLDER as a sample
df_white = df1[df1['Description']=='WHITE HANGING HEART T-LIGHT HOLDER']

# This denotes that WHITE HANGING HEART T-LIGHT HOLDER has been ordered 2028 times
df_white.shape
# Out:
# (2028, 13)

# %%
# This denotes that WHITE HANGING HEART T-LIGHT HOLDER has been ordered by 856 customers
len(df_white.CustomerID.unique())
# Out:
# 856

# %%
# Creating a pivot table that displays the sum of unique Customers who bought particular item
bought_by_most_customers = df1.pivot_table(index=['StockCode','Description'], values='CustomerID', 
                                           aggfunc=lambda x: len(x.unique())).sort_values(by='CustomerID', ascending=False)

bought_by_most_customers
# Out:
#                                               CustomerID
# StockCode Description
# 22423     REGENCY CAKESTAND 3 TIER                   881
# 85123A    WHITE HANGING HEART T-LIGHT HOLDER         856
# 47566     PARTY BUNTING                              708
# 84879     ASSORTED COLOUR BIRD ORNAMENT              678
# 22720     SET OF 3 CAKE TINS PANTRY DESIGN           640
# ...                                                  ...
# 21897     POTTING SHED CANDLE CITRONELLA               1
# 84795C    OCEAN STRIPE HAMMOCK                         1
# 90125E    AMBER BERTIE GLASS BEAD BAG CHARM            1
# 90128B    BLUE LEAVES AND BEADS PHONE CHARM            1
# 71143     SILVER BOOK MARK WITH BEADS                  1
#
# [3897 rows x 1 columns]

# %%
bought_by_most_customers.reset_index(inplace=True)
sns.set_style('white')

# Creating a bar plot of Description ( or the item ) on the Y axis and the sum of unique Customers on the X axis
# We are plotting only the 10 most bought items
sns.barplot(y='Description', x='CustomerID', data=bought_by_most_customers.head(10))

# Giving suitable title to the plot
plt.title('Top 10 Items bought by Most no. of Customers', fontsize=14)

plt.ylabel('Item')
# Out:
# Text(0, 0.5, 'Item')

# %% [markdown]
# ### Most Frequently Ordered Items

# %%
# Preparing data for wordcloud
df1['items'] = df1['Description'].str.replace(' ', '_')

df1.head()
# Out:
#   InvoiceNo StockCode  year_month  month  day  hour  \
# 0    536365    85123A      201012     12    3     8
# 1    536365     71053      201012     12    3     8
# 2    536365    84406B      201012     12    3     8
# 3    536365    84029G      201012     12    3     8
# 4    536365    84029E      201012     12    3     8
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  Amount  \
# 0       2.55     17850.0  United Kingdom   15.30
# 1       3.39     17850.0  United Kingdom   20.34
# 2       2.75     17850.0  United Kingdom   22.00
# 3       3.39     17850.0  United Kingdom   20.34
# 4       3.39     17850.0  United Kingdom   20.34
#
#                                  items
# 0   WHITE_HANGING_HEART_T-LIGHT_HOLDER
# 1                  WHITE_METAL_LANTERN
# 2       CREAM_CUPID_HEARTS_COAT_HANGER
# 3  KNITTED_UNION_FLAG_HOT_WATER_BOTTLE
# 4       RED_WOOLLY_HOTTIE_WHITE_HEART.

# %%
from wordcloud import WordCloud

plt.rcParams['figure.figsize'] = (20, 20)
wordcloud = WordCloud(background_color = 'white', width = 1200,  height = 1200, max_words = 121).generate(str(df1['items']))
plt.imshow(wordcloud)
plt.axis('off')
plt.title('Most Frequently Bought Items',fontsize = 22)
plt.show()

# %% [markdown]
# ### Top 10 First Choices

# %%
# Storing all the invoice numbers into a list y
y = df1['InvoiceNo']
y = y.to_list()

# Length of y
len(y)
# Out:
# 397924

# %%
# Using set function to find unique invoice numbers only and storing them in invoices list
invoices = list(set(y))

# Lenght of invoices ( or count of unique invoice numbers )
len(invoices)
# Out:
# 18536

# %%
# Creating empty list first_choices
first_choices = []

# looping into list of unique invoice numbers
for i in invoices:
    
    # the first item (index = 0) of every invoice is the first purchase
    # extracting the item name for the first purchase
    first_purchase = df1[df1['InvoiceNo']==i]['items'].reset_index(drop=True)[0]
    
    # Appending the first purchase name into first choices list
    first_choices.append(first_purchase)

# First 5 elements
first_choices[:5]
# Out:
# ['PEARLISED_IVORY_HEART_LARGE_',
#  'REGENCY_CAKESTAND_3_TIER',
#  'IVORY_KITCHEN_SCALES',
#  'BASKET_OF_FLOWERS_SEWING_KIT',
#  'SET_OF_12_T-LIGHTS_VINTAGE_DOILY']

# %%
# Length of first_choices mathches the lenght of invoices
len(first_choices)
# Out:
# 18536

# %%
# Using counter to count repeating first choices
count = Counter(first_choices)

# Storing the counter into a datafrane
df_first_choices = pd.DataFrame.from_dict(count, orient='index').reset_index()

# Rename columns as item and count
df_first_choices.rename(columns={'index':'item', 0:'count'},inplace=True)

# Sorting the df based on count
df_first_choices.sort_values(by='count',ascending=False)

df_first_choices
# Out:
#                                   item  count
# 0         PEARLISED_IVORY_HEART_LARGE_      1
# 1             REGENCY_CAKESTAND_3_TIER    203
# 2                 IVORY_KITCHEN_SCALES     35
# 3         BASKET_OF_FLOWERS_SEWING_KIT      4
# 4     SET_OF_12_T-LIGHTS_VINTAGE_DOILY      4
# ...                                ...    ...
# 2630          RED_POLKADOT_COFFEE__MUG      1
# 2631      NUMBER_TILE_COTTAGE_GARDEN_6      1
# 2632               BLOND_DOLL_DOORSTOP      1
# 2633    BEADED_PEARL_HEART_WHITE_LARGE      1
# 2634        HEN_HOUSE_W_CHICK_STANDING      1
#
# [2635 rows x 2 columns]

# %%
plt.subplots(figsize=(20,10))
sns.set_style('white')

# Creating a bar plot that displays Item name on the Y axis and Count on the X axis
sns.barplot(y='item', x='count', data=df_first_choices.sort_values(by='count',ascending=False).head(10))

# Giving suitable title to the plot
plt.title('Top 10 First Choices', fontsize=14)

plt.ylabel('Item')
# Out:
# Text(0, 0.5, 'Item')

# %% [markdown]
# ### Frequently Bought Together

# %% [markdown]
# Market basket analysis is a data mining technique used by retailers to increase sales by better understanding customer purchasing patterns. It involves analyzing large data sets, such as purchase history, to reveal product groupings, as well as products that are likely to be purchased together.
#
# This segment will answer the questions like:
#
# 1. Which items are frequently bought together?
# 2. If a user buys an item X, which item is he/she likely to buy next?

# %%
# Using groupby function to create a basket df, which specifies if an item is present in a particular invoiceno
# for all items and all invoices. This will denote the quantity present in the particular invoiceno which needs to be fixed

basket = (df1.groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))

basket.head(10)
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                  0.0                             0.0
# 536366                                  0.0                             0.0
# 536367                                  0.0                             0.0
# 536368                                  0.0                             0.0
# 536369                                  0.0                             0.0
# 536370                                  0.0                             0.0
# 536371                                  0.0                             0.0
# 536372                                  0.0                             0.0
# 536373                                  0.0                             0.0
# 536374                                  0.0                             0.0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                      0.0                           0.0
# 536366                      0.0                           0.0
# 536367                      0.0                           0.0
# 536368                      0.0                           0.0
# 536369                      0.0                           0.0
# 536370                      0.0                           0.0
# 536371                      0.0                           0.0
# 536372                      0.0                           0.0
# 536373                      0.0                           0.0
# 536374                      0.0                           0.0
#
# Description   I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536365                                0.0                       0.0
# 536366                                0.0                       0.0
# 536367                                0.0                       0.0
# 536368                                0.0                       0.0
# 536369                                0.0                       0.0
# 536370                                0.0                       0.0
# 536371                                0.0                       0.0
# 536372                                0.0                       0.0
# 536373                                0.0                       0.0
# 536374                                0.0                       0.0
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536365                               0.0                       0.0
# 536366                               0.0                       0.0
# 536367                               0.0                       0.0
# 536368                               0.0                       0.0
# 536369                               0.0                       0.0
# 536370                               0.0                       0.0
# 536371                               0.0                       0.0
# 536372                               0.0                       0.0
# 536373                               0.0                       0.0
# 536374                               0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# InvoiceNo                                                               ...
# 536365                                    0.0                      0.0  ...
# 536366                                    0.0                      0.0  ...
# 536367                                    0.0                      0.0  ...
# 536368                                    0.0                      0.0  ...
# 536369                                    0.0                      0.0  ...
# 536370                                   24.0                      0.0  ...
# 536371                                    0.0                      0.0  ...
# 536372                                    0.0                      0.0  ...
# 536373                                    0.0                      0.0  ...
# 536374                                    0.0                      0.0  ...
#
# Description  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# InvoiceNo
# 536365                             0.0                        0.0
# 536366                             0.0                        0.0
# 536367                             0.0                        0.0
# 536368                             0.0                        0.0
# 536369                             0.0                        0.0
# 536370                             0.0                        0.0
# 536371                             0.0                        0.0
# 536372                             0.0                        0.0
# 536373                             0.0                        0.0
# 536374                             0.0                        0.0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536365                                    0.0                             0.0
# 536366                                    0.0                             0.0
# 536367                                    0.0                             0.0
# 536368                                    0.0                             0.0
# 536369                                    0.0                             0.0
# 536370                                    0.0                             0.0
# 536371                                    0.0                             0.0
# 536372                                    0.0                             0.0
# 536373                                    0.0                             0.0
# 536374                                    0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536365                                   0.0                              0.0
# 536366                                   0.0                              0.0
# 536367                                   0.0                              0.0
# 536368                                   0.0                              0.0
# 536369                                   0.0                              0.0
# 536370                                   0.0                              0.0
# 536371                                   0.0                              0.0
# 536372                                   0.0                              0.0
# 536373                                   0.0                              0.0
# 536374                                   0.0                              0.0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# InvoiceNo
# 536365                                  0.0                               0.0
# 536366                                  0.0                               0.0
# 536367                                  0.0                               0.0
# 536368                                  0.0                               0.0
# 536369                                  0.0                               0.0
# 536370                                  0.0                               0.0
# 536371                                  0.0                               0.0
# 536372                                  0.0                               0.0
# 536373                                  0.0                               0.0
# 536374                                  0.0                               0.0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# InvoiceNo
# 536365                               0.0                               0.0
# 536366                               0.0                               0.0
# 536367                               0.0                               0.0
# 536368                               0.0                               0.0
# 536369                               0.0                               0.0
# 536370                               0.0                               0.0
# 536371                               0.0                               0.0
# 536372                               0.0                               0.0
# 536373                               0.0                               0.0
# 536374                               0.0                               0.0
#
# [10 rows x 3877 columns]

# %% [markdown]
# This output gets the quantity ordered (e.g., 48,24,126), but we just want to know if an item was purchased or not. So, let’s encode the units as 1 (if purchased) or 0 (not purchased).

# %%
# Encoding units as 1(if purchased) or 0(not purchased)

def encode_units(x):
    if x < 1:
        return 0
    if x >= 1:
        return 1

basket = basket.applymap(encode_units)

basket.head(10)
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536369                                    0                               0
# 536370                                    0                               0
# 536371                                    0                               0
# 536372                                    0                               0
# 536373                                    0                               0
# 536374                                    0                               0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                        0                             0
# 536366                        0                             0
# 536367                        0                             0
# 536368                        0                             0
# 536369                        0                             0
# 536370                        0                             0
# 536371                        0                             0
# 536372                        0                             0
# 536373                        0                             0
# 536374                        0                             0
#
# Description   I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536365                                  0                         0
# 536366                                  0                         0
# 536367                                  0                         0
# 536368                                  0                         0
# 536369                                  0                         0
# 536370                                  0                         0
# 536371                                  0                         0
# 536372                                  0                         0
# 536373                                  0                         0
# 536374                                  0                         0
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536365                                 0                         0
# 536366                                 0                         0
# 536367                                 0                         0
# 536368                                 0                         0
# 536369                                 0                         0
# 536370                                 0                         0
# 536371                                 0                         0
# 536372                                 0                         0
# 536373                                 0                         0
# 536374                                 0                         0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# InvoiceNo                                                               ...
# 536365                                      0                        0  ...
# 536366                                      0                        0  ...
# 536367                                      0                        0  ...
# 536368                                      0                        0  ...
# 536369                                      0                        0  ...
# 536370                                      1                        0  ...
# 536371                                      0                        0  ...
# 536372                                      0                        0  ...
# 536373                                      0                        0  ...
# 536374                                      0                        0  ...
#
# Description  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# InvoiceNo
# 536365                               0                          0
# 536366                               0                          0
# 536367                               0                          0
# 536368                               0                          0
# 536369                               0                          0
# 536370                               0                          0
# 536371                               0                          0
# 536372                               0                          0
# 536373                               0                          0
# 536374                               0                          0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536365                                      0                               0
# 536366                                      0                               0
# 536367                                      0                               0
# 536368                                      0                               0
# 536369                                      0                               0
# 536370                                      0                               0
# 536371                                      0                               0
# 536372                                      0                               0
# 536373                                      0                               0
# 536374                                      0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536365                                     0                                0
# 536366                                     0                                0
# 536367                                     0                                0
# 536368                                     0                                0
# 536369                                     0                                0
# 536370                                     0                                0
# 536371                                     0                                0
# 536372                                     0                                0
# 536373                                     0                                0
# 536374                                     0                                0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# InvoiceNo
# 536365                                    0                                 0
# 536366                                    0                                 0
# 536367                                    0                                 0
# 536368                                    0                                 0
# 536369                                    0                                 0
# 536370                                    0                                 0
# 536371                                    0                                 0
# 536372                                    0                                 0
# 536373                                    0                                 0
# 536374                                    0                                 0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# InvoiceNo
# 536365                                 0                                 0
# 536366                                 0                                 0
# 536367                                 0                                 0
# 536368                                 0                                 0
# 536369                                 0                                 0
# 536370                                 0                                 0
# 536371                                 0                                 0
# 536372                                 0                                 0
# 536373                                 0                                 0
# 536374                                 0                                 0
#
# [10 rows x 3877 columns]

# %%
# Let's see how many 0's & 1's
counts = pd.Series(basket.values.ravel()).value_counts()

print(counts)
# Out:
# 0    71476300
# 1      387772
# Name: count, dtype: int64

# %% [markdown]
# ### Apriori Algorithm Concepts
# What is Support, Confidence and Lift?

# %% [markdown]
# <div style="text-align:center;">
#     <img src='images/Support_Explanation.jpg' width='600'>
# </div>

# %% [markdown]
# Example : If out of 100 users, 10 purchase Milk then **support for Milk** will be 10/100 = 10% The formula for calculation is as given below :

# %% [markdown]
# <div style="text-align:center;">
#     <img src='images/Support_Formula.jpg' width='600'>
# </div>

# %% [markdown]
# <div style="text-align:center;">
#     <img src='images/Confidence_Explanation.jpg' width='600'>
# </div>

# %% [markdown]
# Suppose you are looking to build a relationship between milk and bread. If 7 out of 40 milk buyers also buy bread, then **confidence** = 7/40 = 17.5%

# %% [markdown]
# The formula to calculate confidence is as given below :

# %% [markdown]
# <div style="text-align:center;">
#     <img src='images/Confidence_Formula.jpg' width='800'>
# </div>

# %% [markdown]
# <div style="text-align:center;">
#     <img src='images/Lift.jpg' width='600'>
# </div>

# %% [markdown]
# $$ Lift = Confidence/Support $$
#
# $$ Lift = 17.5/10 = 1.75 $$

# %% [markdown]
# ## Association Rules

# %% [markdown]
# Association rule mining finds interesting associations and relationships among large sets of data items. This rule shows how frequently a itemset occurs in a transaction. Based on those rules created from the Dataset, we perform Market Basket Analysis.

# %% [markdown]
# <div style="text-align:center;">
#     <img src='images/Rules.png' width='800'>
# </div>

# %% [markdown]
# From the above image, Out of 5 transactions where mobile was purchased, 3 of them has mobile screen guard along with it. Thus it should be recommended

# %% [markdown]
# ### Implementation using mlxtend

# %%
# trying out on a sample item
wooden_star_df = basket.loc[basket['WOODEN STAR CHRISTMAS SCANDINAVIAN']==1]

wooden_star_df.head()
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536572                                    0                               0
# 536643                                    0                               0
# 536833                                    0                               0
# 536987                                    0                               0
# 537047                                    0                               0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536572                        0                             0
# 536643                        0                             0
# 536833                        0                             0
# 536987                        0                             0
# 537047                        0                             0
#
# Description   I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536572                                  0                         0
# 536643                                  0                         0
# 536833                                  0                         0
# 536987                                  0                         0
# 537047                                  0                         0
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536572                                 0                         0
# 536643                                 0                         0
# 536833                                 0                         0
# 536987                                 0                         0
# 537047                                 0                         0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# InvoiceNo                                                               ...
# 536572                                      0                        0  ...
# 536643                                      0                        0  ...
# 536833                                      0                        0  ...
# 536987                                      0                        0  ...
# 537047                                      0                        0  ...
#
# Description  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# InvoiceNo
# 536572                               0                          0
# 536643                               0                          0
# 536833                               0                          0
# 536987                               0                          0
# 537047                               0                          0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536572                                      0                               0
# 536643                                      0                               0
# 536833                                      0                               0
# 536987                                      0                               0
# 537047                                      0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536572                                     0                                0
# 536643                                     0                                0
# 536833                                     0                                0
# 536987                                     0                                0
# 537047                                     0                                0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# InvoiceNo
# 536572                                    0                                 0
# 536643                                    0                                 0
# 536833                                    0                                 0
# 536987                                    0                                 0
# 537047                                    0                                 0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# InvoiceNo
# 536572                                 0                                 0
# 536643                                 0                                 0
# 536833                                 0                                 0
# 536987                                 0                                 0
# 537047                                 0                                 0
#
# [5 rows x 3877 columns]

# %% [markdown]
# <img src='images/atob.png' width='300'>

# %%
# Using apriori algorithm, creating association rules for the sample item

# Applying apriori algorithm for wooden_star_df
frequent_itemsets = apriori(wooden_star_df, min_support=0.15, use_colnames=True)

# Storing the association rules into rules
wooden_star_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Sorting the rules on lift and support
wooden_star_rules.sort_values(['lift','support'],ascending=False).reset_index(drop=True)
# Out:
#                                           antecedents  \
# 0                (WOODEN TREE CHRISTMAS SCANDINAVIAN)
# 1               (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 2   (WOODEN TREE CHRISTMAS SCANDINAVIAN, WOODEN ST...
# 3   (WOODEN STAR CHRISTMAS SCANDINAVIAN, WOODEN HE...
# 4                (WOODEN TREE CHRISTMAS SCANDINAVIAN)
# 5               (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 6                   (PAPER CHAIN KIT 50'S CHRISTMAS )
# 7               (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 8   (WOODEN STAR CHRISTMAS SCANDINAVIAN, PAPER CHA...
# 9   (WOODEN STAR CHRISTMAS SCANDINAVIAN, WOODEN HE...
# 10                  (PAPER CHAIN KIT 50'S CHRISTMAS )
# 11              (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 12                (SET OF 3 WOODEN HEART DECORATIONS)
# 13              (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 14  (SET OF 3 WOODEN HEART DECORATIONS, WOODEN STA...
# 15  (WOODEN STAR CHRISTMAS SCANDINAVIAN, WOODEN HE...
# 16                (SET OF 3 WOODEN HEART DECORATIONS)
# 17              (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 18               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 19              (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 20               (WOODEN TREE CHRISTMAS SCANDINAVIAN)
# 21               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 22  (WOODEN TREE CHRISTMAS SCANDINAVIAN, WOODEN HE...
# 23               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 24               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 25                  (PAPER CHAIN KIT 50'S CHRISTMAS )
# 26                (SET OF 3 WOODEN HEART DECORATIONS)
# 27               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 28              (SET OF 3 WOODEN STOCKING DECORATION)
# 29               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 30               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 31                 (SET OF 3 WOODEN TREE DECORATIONS)
# 32  (WOODEN HEART CHRISTMAS SCANDINAVIAN, PAPER CH...
# 33               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 34               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 35               (WHITE HANGING HEART T-LIGHT HOLDER)
# 36               (SET OF 3 WOODEN SLEIGH DECORATIONS)
# 37               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 38                        (ZINC FOLKART SLEIGH BELLS)
# 39               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 40  (SET OF 3 WOODEN HEART DECORATIONS, WOODEN HEA...
# 41               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
#
#                                           consequents  antecedent support  \
# 0               (WOODEN HEART CHRISTMAS SCANDINAVIAN)            0.521940
# 1                (WOODEN TREE CHRISTMAS SCANDINAVIAN)            0.736721
# 2               (WOODEN HEART CHRISTMAS SCANDINAVIAN)            0.521940
# 3                (WOODEN TREE CHRISTMAS SCANDINAVIAN)            0.736721
# 4   (WOODEN STAR CHRISTMAS SCANDINAVIAN, WOODEN HE...            0.521940
# 5   (WOODEN TREE CHRISTMAS SCANDINAVIAN, WOODEN ST...            0.736721
# 6               (WOODEN HEART CHRISTMAS SCANDINAVIAN)            0.221709
# 7                   (PAPER CHAIN KIT 50'S CHRISTMAS )            0.736721
# 8               (WOODEN HEART CHRISTMAS SCANDINAVIAN)            0.221709
# 9                   (PAPER CHAIN KIT 50'S CHRISTMAS )            0.736721
# 10  (WOODEN STAR CHRISTMAS SCANDINAVIAN, WOODEN HE...            0.221709
# 11  (WOODEN STAR CHRISTMAS SCANDINAVIAN, PAPER CHA...            0.736721
# 12              (WOODEN HEART CHRISTMAS SCANDINAVIAN)            0.198614
# 13                (SET OF 3 WOODEN HEART DECORATIONS)            0.736721
# 14              (WOODEN HEART CHRISTMAS SCANDINAVIAN)            0.198614
# 15                (SET OF 3 WOODEN HEART DECORATIONS)            0.736721
# 16  (WOODEN STAR CHRISTMAS SCANDINAVIAN, WOODEN HE...            0.198614
# 17  (SET OF 3 WOODEN HEART DECORATIONS, WOODEN STA...            0.736721
# 18              (WOODEN HEART CHRISTMAS SCANDINAVIAN)            1.000000
# 19               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.736721
# 20               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.521940
# 21               (WOODEN TREE CHRISTMAS SCANDINAVIAN)            1.000000
# 22               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.420323
# 23  (WOODEN TREE CHRISTMAS SCANDINAVIAN, WOODEN HE...            1.000000
# 24                  (PAPER CHAIN KIT 50'S CHRISTMAS )            1.000000
# 25               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.221709
# 26               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.198614
# 27                (SET OF 3 WOODEN HEART DECORATIONS)            1.000000
# 28               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.182448
# 29              (SET OF 3 WOODEN STOCKING DECORATION)            1.000000
# 30                 (SET OF 3 WOODEN TREE DECORATIONS)            1.000000
# 31               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.182448
# 32               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.177829
# 33  (WOODEN HEART CHRISTMAS SCANDINAVIAN, PAPER CH...            1.000000
# 34               (WHITE HANGING HEART T-LIGHT HOLDER)            1.000000
# 35               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.170901
# 36               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.163972
# 37               (SET OF 3 WOODEN SLEIGH DECORATIONS)            1.000000
# 38               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.163972
# 39                        (ZINC FOLKART SLEIGH BELLS)            1.000000
# 40               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.152425
# 41  (SET OF 3 WOODEN HEART DECORATIONS, WOODEN HEA...            1.000000
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.736721  0.420323    0.805310  1.093101  0.035799    1.352299
# 1             0.521940  0.420323    0.570533  1.093101  0.035799    1.113147
# 2             0.736721  0.420323    0.805310  1.093101  0.035799    1.352299
# 3             0.521940  0.420323    0.570533  1.093101  0.035799    1.113147
# 4             0.736721  0.420323    0.805310  1.093101  0.035799    1.352299
# 5             0.521940  0.420323    0.570533  1.093101  0.035799    1.113147
# 6             0.736721  0.177829    0.802083  1.088721  0.014492    1.330254
# 7             0.221709  0.177829    0.241379  1.088721  0.014492    1.025929
# 8             0.736721  0.177829    0.802083  1.088721  0.014492    1.330254
# 9             0.221709  0.177829    0.241379  1.088721  0.014492    1.025929
# 10            0.736721  0.177829    0.802083  1.088721  0.014492    1.330254
# 11            0.221709  0.177829    0.241379  1.088721  0.014492    1.025929
# 12            0.736721  0.152425    0.767442  1.041700  0.006102    1.132102
# 13            0.198614  0.152425    0.206897  1.041700  0.006102    1.010443
# 14            0.736721  0.152425    0.767442  1.041700  0.006102    1.132102
# 15            0.198614  0.152425    0.206897  1.041700  0.006102    1.010443
# 16            0.736721  0.152425    0.767442  1.041700  0.006102    1.132102
# 17            0.198614  0.152425    0.206897  1.041700  0.006102    1.010443
# 18            0.736721  0.736721    0.736721  1.000000  0.000000    1.000000
# 19            1.000000  0.736721    1.000000  1.000000  0.000000         inf
# 20            1.000000  0.521940    1.000000  1.000000  0.000000         inf
# 21            0.521940  0.521940    0.521940  1.000000  0.000000    1.000000
# 22            1.000000  0.420323    1.000000  1.000000  0.000000         inf
# 23            0.420323  0.420323    0.420323  1.000000  0.000000    1.000000
# 24            0.221709  0.221709    0.221709  1.000000  0.000000    1.000000
# 25            1.000000  0.221709    1.000000  1.000000  0.000000         inf
# 26            1.000000  0.198614    1.000000  1.000000  0.000000         inf
# 27            0.198614  0.198614    0.198614  1.000000  0.000000    1.000000
# 28            1.000000  0.182448    1.000000  1.000000  0.000000         inf
# 29            0.182448  0.182448    0.182448  1.000000  0.000000    1.000000
# 30            0.182448  0.182448    0.182448  1.000000  0.000000    1.000000
# 31            1.000000  0.182448    1.000000  1.000000  0.000000         inf
# 32            1.000000  0.177829    1.000000  1.000000  0.000000         inf
# 33            0.177829  0.177829    0.177829  1.000000  0.000000    1.000000
# 34            0.170901  0.170901    0.170901  1.000000  0.000000    1.000000
# 35            1.000000  0.170901    1.000000  1.000000  0.000000         inf
# 36            1.000000  0.163972    1.000000  1.000000  0.000000         inf
# 37            0.163972  0.163972    0.163972  1.000000  0.000000    1.000000
# 38            1.000000  0.163972    1.000000  1.000000  0.000000         inf
# 39            0.163972  0.163972    0.163972  1.000000  0.000000    1.000000
# 40            1.000000  0.152425    1.000000  1.000000  0.000000         inf
# 41            0.152425  0.152425    0.152425  1.000000  0.000000    1.000000
#
#     zhangs_metric
# 0        0.178160
# 1        0.323501
# 2        0.178160
# 3        0.323501
# 4        0.178160
# 5        0.323501
# 6        0.104705
# 7        0.309524
# 8        0.104705
# 9        0.309524
# 10       0.104705
# 11       0.309524
# 12       0.049952
# 13       0.152047
# 14       0.049952
# 15       0.152047
# 16       0.049952
# 17       0.152047
# 18       0.000000
# 19       0.000000
# 20       0.000000
# 21       0.000000
# 22       0.000000
# 23       0.000000
# 24       0.000000
# 25       0.000000
# 26       0.000000
# 27       0.000000
# 28       0.000000
# 29       0.000000
# 30       0.000000
# 31       0.000000
# 32       0.000000
# 33       0.000000
# 34       0.000000
# 35       0.000000
# 36       0.000000
# 37       0.000000
# 38       0.000000
# 39       0.000000
# 40       0.000000
# 41       0.000000

# %% [markdown]
# mlxtend Docs: http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/#association-rules-generation-from-frequent-itemsets

# %% [markdown]
# ### Creating the function

# %% [markdown]
# Creating a new function in which we pass an item name and it returns the items which are frequently bought together. In other words, it returns the items which are likely to be bought by user because he bought the item passed into function

# %%
def frequently_bought_together(item):
    
    # df of item passed
    item_df = basket.loc[basket[item]==1]
    
    # Applying apriori algorithm on item df
    frequent_itemsets = apriori(item_df, min_support=0.15, use_colnames=True)
    
    # Storing association rules
    rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
    
    # Sorting on lift and support
    rules.sort_values(['lift','support'],ascending=False).reset_index(drop=True)
    
    print('Items frequently bought together with {0}'.format(item))
    
    # Returning top 6 items with highest lift and support
    return rules['consequents'].unique()[:6]

# %%
# Example 1
frequently_bought_together('WOODEN STAR CHRISTMAS SCANDINAVIAN')
# Out:
# Items frequently bought together with WOODEN STAR CHRISTMAS SCANDINAVIAN
# array([frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN'}),
#        frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS "}),
#        frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}),
#        frozenset({'SET OF 3 WOODEN HEART DECORATIONS'}),
#        frozenset({'SET OF 3 WOODEN SLEIGH DECORATIONS'}),
#        frozenset({'SET OF 3 WOODEN STOCKING DECORATION'})], dtype=object)

# %%
# Example 2
frequently_bought_together('WHITE METAL LANTERN')
# Out:
# Items frequently bought together with WHITE METAL LANTERN
# array([frozenset({'LANTERN CREAM GAZEBO '}),
#        frozenset({'WHITE METAL LANTERN'}),
#        frozenset({'REGENCY CAKESTAND 3 TIER'}),
#        frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'})], dtype=object)

# %%
# Example 3
frequently_bought_together('JAM MAKING SET WITH JARS')
# Out:
# Items frequently bought together with JAM MAKING SET WITH JARS
# array([frozenset({'JAM MAKING SET PRINTED'}),
#        frozenset({'JAM MAKING SET WITH JARS'}),
#        frozenset({'PACK OF 72 RETROSPOT CAKE CASES'}),
#        frozenset({'RECIPE BOX PANTRY YELLOW DESIGN'}),
#        frozenset({'REGENCY CAKESTAND 3 TIER'}),
#        frozenset({'SET OF 3 CAKE TINS PANTRY DESIGN '})], dtype=object)

# %% [markdown]
# ### Validation

# %%
# JAM MAKING SET PRINTED is a part of invoice 536390, so we will print all items from invoice 536390 and cross-check 
df1[df1['InvoiceNo']=='536390']

# There are a couple of common items between the recommendations from frequently_bought_together and the invoice below
# Thus we can say the recommender is performing well
# Out:
#     InvoiceNo StockCode  year_month  month  day  hour  \
# 211    536390     22941      201012     12    3    10
# 212    536390     22960      201012     12    3    10
# 213    536390     22961      201012     12    3    10
# 214    536390     22962      201012     12    3    10
# 215    536390     22963      201012     12    3    10
# 216    536390     22968      201012     12    3    10
# 217    536390    84970S      201012     12    3    10
# 218    536390     22910      201012     12    3    10
# 219    536390     20668      201012     12    3    10
# 220    536390    85123A      201012     12    3    10
# 221    536390     22197      201012     12    3    10
# 222    536390     22198      201012     12    3    10
# 223    536390     21533      201012     12    3    10
# 224    536390     21080      201012     12    3    10
# 225    536390     21094      201012     12    3    10
# 226    536390     21086      201012     12    3    10
# 227    536390     21786      201012     12    3    10
# 228    536390     22654      201012     12    3    10
# 229    536390     21485      201012     12    3    10
# 230    536390    84029G      201012     12    3    10
# 231    536390    84030E      201012     12    3    10
# 232    536390     22174      201012     12    3    10
# 233    536390     22969      201012     12    3    10
# 234    536390    85099B      201012     12    3    10
#
#                              Description  Quantity         InvoiceDate  \
# 211         CHRISTMAS LIGHTS 10 REINDEER         2 2010-12-01 10:19:00
# 212             JAM MAKING SET WITH JARS        12 2010-12-01 10:19:00
# 213               JAM MAKING SET PRINTED        12 2010-12-01 10:19:00
# 214                JAM JAR WITH PINK LID        48 2010-12-01 10:19:00
# 215               JAM JAR WITH GREEN LID        48 2010-12-01 10:19:00
# 216           ROSE COTTAGE KEEPSAKE BOX          8 2010-12-01 10:19:00
# 217    HANGING HEART ZINC T-LIGHT HOLDER       144 2010-12-01 10:19:00
# 218    PAPER CHAIN KIT VINTAGE CHRISTMAS        40 2010-12-01 10:19:00
# 219      DISCO BALL CHRISTMAS DECORATION       288 2010-12-01 10:19:00
# 220   WHITE HANGING HEART T-LIGHT HOLDER        64 2010-12-01 10:19:00
# 221                 SMALL POPCORN HOLDER       100 2010-12-01 10:19:00
# 222                LARGE POPCORN HOLDER         50 2010-12-01 10:19:00
# 223             RETROSPOT LARGE MILK JUG        12 2010-12-01 10:19:00
# 224  SET/20 RED RETROSPOT PAPER NAPKINS         96 2010-12-01 10:19:00
# 225        SET/6 RED SPOTTY PAPER PLATES        96 2010-12-01 10:19:00
# 226          SET/6 RED SPOTTY PAPER CUPS        48 2010-12-01 10:19:00
# 227                   POLKADOT RAIN HAT        144 2010-12-01 10:19:00
# 228                   DELUXE SEWING KIT         40 2010-12-01 10:19:00
# 229     RETROSPOT HEART HOT WATER BOTTLE        24 2010-12-01 10:19:00
# 230  KNITTED UNION FLAG HOT WATER BOTTLE        24 2010-12-01 10:19:00
# 231        ENGLISH ROSE HOT WATER BOTTLE        24 2010-12-01 10:19:00
# 232                           PHOTO CUBE        48 2010-12-01 10:19:00
# 233         HOMEMADE JAM SCENTED CANDLES        96 2010-12-01 10:19:00
# 234              JUMBO BAG RED RETROSPOT       100 2010-12-01 10:19:00
#
#      UnitPrice  CustomerID         Country  Amount  \
# 211       8.50     17511.0  United Kingdom   17.00
# 212       3.75     17511.0  United Kingdom   45.00
# 213       1.45     17511.0  United Kingdom   17.40
# 214       0.72     17511.0  United Kingdom   34.56
# 215       0.72     17511.0  United Kingdom   34.56
# 216       8.50     17511.0  United Kingdom   68.00
# 217       0.64     17511.0  United Kingdom   92.16
# 218       2.55     17511.0  United Kingdom  102.00
# 219       0.10     17511.0  United Kingdom   28.80
# 220       2.55     17511.0  United Kingdom  163.20
# 221       0.72     17511.0  United Kingdom   72.00
# 222       1.45     17511.0  United Kingdom   72.50
# 223       4.25     17511.0  United Kingdom   51.00
# 224       0.64     17511.0  United Kingdom   61.44
# 225       0.64     17511.0  United Kingdom   61.44
# 226       0.65     17511.0  United Kingdom   31.20
# 227       0.32     17511.0  United Kingdom   46.08
# 228       4.95     17511.0  United Kingdom  198.00
# 229       4.25     17511.0  United Kingdom  102.00
# 230       3.39     17511.0  United Kingdom   81.36
# 231       3.75     17511.0  United Kingdom   90.00
# 232       1.48     17511.0  United Kingdom   71.04
# 233       1.25     17511.0  United Kingdom  120.00
# 234       1.65     17511.0  United Kingdom  165.00
#
#                                    items
# 211         CHRISTMAS_LIGHTS_10_REINDEER
# 212             JAM_MAKING_SET_WITH_JARS
# 213               JAM_MAKING_SET_PRINTED
# 214                JAM_JAR_WITH_PINK_LID
# 215               JAM_JAR_WITH_GREEN_LID
# 216           ROSE_COTTAGE_KEEPSAKE_BOX_
# 217    HANGING_HEART_ZINC_T-LIGHT_HOLDER
# 218    PAPER_CHAIN_KIT_VINTAGE_CHRISTMAS
# 219      DISCO_BALL_CHRISTMAS_DECORATION
# 220   WHITE_HANGING_HEART_T-LIGHT_HOLDER
# 221                 SMALL_POPCORN_HOLDER
# 222                LARGE_POPCORN_HOLDER_
# 223             RETROSPOT_LARGE_MILK_JUG
# 224  SET/20_RED_RETROSPOT_PAPER_NAPKINS_
# 225        SET/6_RED_SPOTTY_PAPER_PLATES
# 226          SET/6_RED_SPOTTY_PAPER_CUPS
# 227                   POLKADOT_RAIN_HAT_
# 228                   DELUXE_SEWING_KIT_
# 229     RETROSPOT_HEART_HOT_WATER_BOTTLE
# 230  KNITTED_UNION_FLAG_HOT_WATER_BOTTLE
# 231        ENGLISH_ROSE_HOT_WATER_BOTTLE
# 232                           PHOTO_CUBE
# 233         HOMEMADE_JAM_SCENTED_CANDLES
# 234              JUMBO_BAG_RED_RETROSPOT

# %% [markdown]
# There are some common items between the recommendations from the bought_together_frequently function and the invoice. Thus, the recommender is performing well.

# %% [markdown]
# ### Visualization of Association Rules

# %%
# For a sample, we will try out visualization techniques on Wooden Star df which we used earlier

support=wooden_star_rules.support.values
confidence=wooden_star_rules.confidence.values

# %%
import networkx as nx

# %%
import random
import matplotlib.pyplot as plt
 
for i in range (len(support)):
    support[i] = support[i] + 0.0025 * (random.randint(1,10) - 5) 
    confidence[i] = confidence[i] + 0.0025 * (random.randint(1,10) - 5)
    

# Set the figure size to make the graph shorter
plt.figure(figsize=(6, 4))

# Creating a scatter plot of support v confidence    
plt.scatter(support, confidence,   alpha=0.5, marker="*")
plt.xlabel('support')
plt.ylabel('confidence') 

# Adding the grid with specific intervals
plt.grid(which='both', axis='both', linestyle='--', linewidth=0.5)
plt.xticks([i * 0.1 for i in range(11)])
plt.yticks([i * 0.2 for i in range(6)])

plt.show()

# %% [markdown]
# Let’s plot a graphical representation.

# %%
def wooden_star_graph(wooden_star_rules, no_of_rules):
    G1 = nx.DiGraph()
    
    color_map = []
    N = 50
    colors = np.random.rand(N)    
    strs = ['R0', 'R1', 'R2', 'R3', 'R4', 'R5', 'R6', 'R7', 'R8', 'R9', 'R10', 'R11']   
    
    for i in range(no_of_rules):      
        # adding as many nodes as number of rules requested by user
        G1.add_nodes_from(["R" + str(i)])
        
        # adding antecedents to the nodes 
        for a in wooden_star_rules.iloc[i]['antecedents']:
            G1.add_nodes_from([a])
            G1.add_edge(a, "R" + str(i), color=colors[i], weight=2)
        
        # adding consequents to the nodes
        for c in wooden_star_rules.iloc[i]['consequents']:
            G1.add_nodes_from([c])
            G1.add_edge("R" + str(i), c, color=colors[i], weight=2)
    
    for node in G1:
        found_a_string = False
        for item in strs: 
            if node == item:
                found_a_string = True
        if found_a_string:
            color_map.append('yellow')
        else:
            color_map.append('green')       
    
    edges = G1.edges()
    colors = [G1[u][v]['color'] for u, v in edges]
    weights = [G1[u][v]['weight'] for u, v in edges]
    
    pos = nx.spring_layout(G1, k=16, scale=1)
    nx.draw(G1, pos, node_color=color_map, edge_color=colors, width=weights, font_size=16, with_labels=False)            
    
    for p in pos:  # raise text positions
        pos[p][1] += 0.07
    nx.draw_networkx_labels(G1, pos)

    plt.show()
    

# Call the function
wooden_star_graph(wooden_star_rules, 5)

# %%
def visualize_rules(item, no_of_rules):
    
    # df of item passed
    item_df = basket.loc[basket[item]==1]
    
    # Applying apriori algorithm on item df
    frequent_itemsets = apriori(item_df, min_support=0.15, use_colnames=True)
    
    # Storing association rules
    rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
    
    # Sorting on lift and support
    rules = rules.sort_values(['lift','support'], ascending=False).reset_index(drop=True)
    
    print('Items frequently bought together with {0}'.format(item))
    
    # Returning top 6 items with highest lift and support
    print(rules['consequents'].unique()[:6])
    
    # Adding some randomness to support and confidence for visualization
    support = rules.support.values + 0.0025 * (np.random.randint(1, 11, size=len(rules)) - 5)
    confidence = rules.confidence.values + 0.0025 * (np.random.randint(1, 11, size=len(rules)) - 5)
    
    # Creating scatter plot of support v confidence  
    plt.figure(figsize=(10, 6))
    plt.scatter(support, confidence, alpha=0.5, marker="*")
    plt.title('Support vs Confidence graph')
    plt.xlabel('Support')
    plt.ylabel('Confidence') 
    plt.show()  
    
    # Creating a new digraph  
    G1 = nx.DiGraph()
   
    color_map = []
    N = 50
    colors = np.random.rand(N)    
    strs = ['R0', 'R1', 'R2', 'R3', 'R4', 'R5', 'R6', 'R7', 'R8', 'R9', 'R10', 'R11']  # Example strings
   
    # adding as many nodes as number of rules requested by user 
    for i in range(no_of_rules):      
        G1.add_nodes_from(["R"+str(i)])
        
        # adding antecedents to the nodes 
        for a in rules.iloc[i]['antecedents']:
            G1.add_nodes_from([a])
            G1.add_edge(a, "R"+str(i), color=colors[i], weight=2)
    
        # adding consequents to the nodes
        for c in rules.iloc[i]['consequents']:
            G1.add_nodes_from([c])
            G1.add_edge("R"+str(i), c, color=colors[i], weight=2)
 
    # Coloring nodes based on their types
    for node in G1:
        if node in strs:
            color_map.append('yellow')
        else:
            color_map.append('green')
 
    print('Visualization of Rules')
  
    # Extracting edge attributes for drawing
    edges = G1.edges()
    edge_colors = [G1[u][v]['color'] for u, v in edges]
    edge_weights = [G1[u][v]['weight'] for u, v in edges]
 
    # Spring layout for node positioning
    pos = nx.spring_layout(G1, k=16, scale=1)
    
    # Drawing nodes and edges
    nx.draw(G1, pos, node_color=color_map, edge_color=edge_colors, width=edge_weights, font_size=16, with_labels=False)
    
    # Adjusting node labels positions
    for p in pos:
        pos[p][1] += 0.07
    
    # Adding node labels
    nx.draw_networkx_labels(G1, pos)
    
    plt.show()


visualize_rules('WOODEN STAR CHRISTMAS SCANDINAVIAN',4)
# Out:
# Items frequently bought together with WOODEN STAR CHRISTMAS SCANDINAVIAN
# [frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN'})
#  frozenset({'WOODEN TREE CHRISTMAS SCANDINAVIAN'})
#  frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN', 'WOODEN HEART CHRISTMAS SCANDINAVIAN'})
#  frozenset({'WOODEN TREE CHRISTMAS SCANDINAVIAN', 'WOODEN STAR CHRISTMAS SCANDINAVIAN'})
#  frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS "})
#  frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN', "PAPER CHAIN KIT 50'S CHRISTMAS "})]
# Visualization of Rules

# %%
visualize_rules('JAM MAKING SET WITH JARS',6)
# Out:
# Items frequently bought together with JAM MAKING SET WITH JARS
# [frozenset({'JAM MAKING SET PRINTED'})
#  frozenset({'JAM MAKING SET WITH JARS'})
#  frozenset({'SET OF 3 CAKE TINS PANTRY DESIGN '})
#  frozenset({'RECIPE BOX PANTRY YELLOW DESIGN'})
#  frozenset({'SET OF 4 PANTRY JELLY MOULDS'})
#  frozenset({'REGENCY CAKESTAND 3 TIER'})]
# Visualization of Rules

# %% [markdown]
# ### Trending Items

# %%
df1.head()
# Out:
#   InvoiceNo StockCode  year_month  month  day  hour  \
# 0    536365    85123A      201012     12    3     8
# 1    536365     71053      201012     12    3     8
# 2    536365    84406B      201012     12    3     8
# 3    536365    84029G      201012     12    3     8
# 4    536365    84029E      201012     12    3     8
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  Amount  \
# 0       2.55     17850.0  United Kingdom   15.30
# 1       3.39     17850.0  United Kingdom   20.34
# 2       2.75     17850.0  United Kingdom   22.00
# 3       3.39     17850.0  United Kingdom   20.34
# 4       3.39     17850.0  United Kingdom   20.34
#
#                                  items
# 0   WHITE_HANGING_HEART_T-LIGHT_HOLDER
# 1                  WHITE_METAL_LANTERN
# 2       CREAM_CUPID_HEARTS_COAT_HANGER
# 3  KNITTED_UNION_FLAG_HOT_WATER_BOTTLE
# 4       RED_WOOLLY_HOTTIE_WHITE_HEART.

# %%
# Invoice Date is in the form datetime(year, month, day, hour, minute, second, milliseconds)
# We are converting it into datetime(year, month, day) to make the input user-fr

df1['date'] = df1['InvoiceDate'].map(lambda x: x.strftime('%y-%m-%d'))

df1['date']
# Out:
# 0         10-12-01
# 1         10-12-01
# 2         10-12-01
# 3         10-12-01
# 4         10-12-01
#             ...
# 541904    11-12-09
# 541905    11-12-09
# 541906    11-12-09
# 541907    11-12-09
# 541908    11-12-09
# Name: date, Length: 397924, dtype: object

# %%
df1.head()
# Out:
#   InvoiceNo StockCode  year_month  month  day  hour  \
# 0    536365    85123A      201012     12    3     8
# 1    536365     71053      201012     12    3     8
# 2    536365    84406B      201012     12    3     8
# 3    536365    84029G      201012     12    3     8
# 4    536365    84029E      201012     12    3     8
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  Amount  \
# 0       2.55     17850.0  United Kingdom   15.30
# 1       3.39     17850.0  United Kingdom   20.34
# 2       2.75     17850.0  United Kingdom   22.00
# 3       3.39     17850.0  United Kingdom   20.34
# 4       3.39     17850.0  United Kingdom   20.34
#
#                                  items      date
# 0   WHITE_HANGING_HEART_T-LIGHT_HOLDER  10-12-01
# 1                  WHITE_METAL_LANTERN  10-12-01
# 2       CREAM_CUPID_HEARTS_COAT_HANGER  10-12-01
# 3  KNITTED_UNION_FLAG_HOT_WATER_BOTTLE  10-12-01
# 4       RED_WOOLLY_HOTTIE_WHITE_HEART.  10-12-01

# %%
datewise_sales = df1.pivot_table(index=['date','StockCode','Description'], values='Quantity', aggfunc='sum').reset_index()

datewise_sales.head()
# Out:
#        date StockCode                   Description  Quantity
# 0  10-12-01     10002   INFLATABLE POLITICAL GLOBE         60
# 1  10-12-01     10125       MINI FUNKY DESIGN TAPES         2
# 2  10-12-01     10133  COLOURING PENCILS BROWN TUBE         5
# 3  10-12-01    15044B           BLUE PAPER PARASOL          1
# 4  10-12-01   15056BL       EDWARDIAN PARASOL BLACK        20

# %%
def trending(date):
    sns.barplot(y='Description', x='Quantity', data=datewise_sales[datewise_sales['date']==date].sort_values(by='Quantity', ascending=False).head(10))
    plt.title('Top 10 Most Selling Items on {0}'.format(date), fontsize=14)
    plt.ylabel('Item')

# %%
trending('10-12-01')

# %%
trending('10-12-03')

# %% [markdown]
# ### Deal Of The Day

# %%
def deal_of_the_day(date):
    
    # sorting the data on given date based on quantity (ascending)
    data = datewise_sales[datewise_sales['date']==date].sort_values(by='Quantity')
    
    print('The most appropriate items to provide Deals on {0} are :'.format(date))
    print(data['Description'].head(10))

# %%
deal_of_the_day('10-12-01')
# Out:
# The most appropriate items to provide Deals on 10-12-01 are :
# 188     SET OF 4 ROSE BOTANICAL CANDLES
# 722        WOODEN ADVENT CALENDAR CREAM
# 706                HERB MARKER ROSEMARY
# 705                   HERB MARKER THYME
# 382    CAKE STAND LOVEBIRD 2 TIER WHITE
# 189          VINTAGE UNION JACK BUNTING
# 192    SQUARE FLOOR CUSHION VINTAGE RED
# 697    PACK OF 20 NAPKINS PANTRY DESIGN
# 196     MILK BOTTLE WITH GLASS STOPPER
# 197                  GLASS  BEURRE DISH
# Name: Description, dtype: object

# %%
deal_of_the_day('10-12-02')
# Out:
# The most appropriate items to provide Deals on 10-12-02 are :
# 1854                               POSTAGE
# 1098                   CLASSIC WHITE FRAME
# 1525     RECIPE BOX BLUE SKETCHBOOK DESIGN
# 1524            TOY TIDY DOLLY GIRL DESIGN
# 1104                  TOAST ITS - DINOSAUR
# 1105                JOY LARGE WOOD LETTERS
# 1519           VINTAGE RED KITCHEN CABINET
# 1513          STRAWBERRY FAIRY CAKE TEAPOT
# 1560        FELTCRAFT PRINCESS OLIVIA DOLL
# 1512    CERAMIC STRAWBERRY CAKE MONEY BANK
# Name: Description, dtype: object

# %%
deal_of_the_day('10-12-03')
# Out:
# The most appropriate items to provide Deals on 10-12-03 are :
# 1855           INFLATABLE POLITICAL GLOBE
# 2000            VINTAGE UNION JACK BUNTING
# 2163                GLASS JAR KINGS CHOICE
# 2006             PAISLEY PATTERN  STICKERS
# 2017               MA CAMPAGNE CUTLERY BOX
# 2018                       SHOE SHINE BOX
# 2357           RED COAT RACK PARIS FASHION
# 2356        YELLOW COAT RACK PARIS FASHION
# 2346    SET 20 NAPKINS FAIRY CAKES DESIGN
# 2026                EIGHT PIECE SNAKE  SET
# Name: Description, dtype: object
