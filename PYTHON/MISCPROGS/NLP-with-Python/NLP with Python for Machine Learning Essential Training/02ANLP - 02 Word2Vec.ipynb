# %% [markdown]
# # Word2Vec: How to implement it

# %% [markdown]
# **Word2vec** is the first method we're going to explore to try to create that numeric representation. In the final chapter of this course, we'll compare all techniques to one another to understand where each one excels. Now to frame this, it's worth noting that word2vec stands for word to vector. So it will convert a word or a string of characters to a numeric vector. Let's start with a formal definition. *"Word2vec is a shallow, two-layer neural network "that accepts a text corpus as an input, "and it returns a set of vectors, "also known as embeddings; "each vector is a numeric representation "of a given word."* In practical terms, you would train this word2vec neural network on some very large corpus of text.

# %% [markdown]
# ### Explore Pre-trained Embeddings
#
# Some other options:
# - `glove-twitter-{25/50/100/200}`
# - `glove-wiki-gigaword-{50/200/300}`
# - `word2vec-google-news-300`
# - `word2vec-ruscorpora-news-300`

# %%
# Install gensim
#!pip install -U gensim

# %% [markdown]
# Load the Wikipedia embeddings and the 100 at the end indicates that each vector should be of length 100. You can alter this if you train your own data.

# %%
# Load pretrained word vectors using gensim
import gensim.downloader as api

wiki_embeddings = api.load('glove-wiki-gigaword-100')

# %%
# Explore the word vector for "king"
wiki_embeddings['king']
# Out:
# array([-0.32307 , -0.87616 ,  0.21977 ,  0.25268 ,  0.22976 ,  0.7388  ,
#        -0.37954 , -0.35307 , -0.84369 , -1.1113  , -0.30266 ,  0.33178 ,
#        -0.25113 ,  0.30448 , -0.077491, -0.89815 ,  0.092496, -1.1407  ,
#        -0.58324 ,  0.66869 , -0.23122 , -0.95855 ,  0.28262 , -0.078848,
#         0.75315 ,  0.26584 ,  0.3422  , -0.33949 ,  0.95608 ,  0.065641,
#         0.45747 ,  0.39835 ,  0.57965 ,  0.39267 , -0.21851 ,  0.58795 ,
#        -0.55999 ,  0.63368 , -0.043983, -0.68731 , -0.37841 ,  0.38026 ,
#         0.61641 , -0.88269 , -0.12346 , -0.37928 , -0.38318 ,  0.23868 ,
#         0.6685  , -0.43321 , -0.11065 ,  0.081723,  1.1569  ,  0.78958 ,
#        -0.21223 , -2.3211  , -0.67806 ,  0.44561 ,  0.65707 ,  0.1045  ,
#         0.46217 ,  0.19912 ,  0.25802 ,  0.057194,  0.53443 , -0.43133 ,
#        -0.34311 ,  0.59789 , -0.58417 ,  0.068995,  0.23944 , -0.85181 ,
#         0.30379 , -0.34177 , -0.25746 , -0.031101, -0.16285 ,  0.45169 ,
#        -0.91627 ,  0.64521 ,  0.73281 , -0.22752 ,  0.30226 ,  0.044801,
#        -0.83741 ,  0.55006 , -0.52506 , -1.7357  ,  0.4751  , -0.70487 ,
#         0.056939, -0.7132  ,  0.089623,  0.41394 , -1.3363  , -0.61915 ,
#        -0.33089 , -0.52881 ,  0.16483 , -0.98878 ], dtype=float32)

# %%
# Find the words most similar to king based on the trained word vectors
wiki_embeddings.most_similar('king')
# Out:
# [('prince', 0.7682328820228577),
#  ('queen', 0.7507690787315369),
#  ('son', 0.7020887136459351),
#  ('brother', 0.6985775828361511),
#  ('monarch', 0.6977891325950623),
#  ('throne', 0.691999077796936),
#  ('kingdom', 0.6811409592628479),
#  ('father', 0.680202841758728),
#  ('emperor', 0.6712858080863953),
#  ('ii', 0.6676074862480164)]

# %%
wiki_embeddings.most_similar('pansy')
# Out:
# [('lorelei', 0.5161975622177124),
#  ('neang', 0.4673246145248413),
#  ('fanta', 0.46462252736091614),
#  ('itsy', 0.46324679255485535),
#  ('damsel', 0.4551335871219635),
#  ('mako', 0.45218175649642944),
#  ('phuong', 0.45166337490081787),
#  ('aqua', 0.448862761259079),
#  ('s.k.', 0.44639748334884644),
#  ('bubblegum', 0.4431919455528259)]

# %% [markdown]
# ### Train Our Own Model

# %%
# Read in the data and clean up column names
import gensim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', 100)

messages = pd.read_csv('data/spam.csv', encoding='latin-1')
messages = messages.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)
messages.columns = ["label", "text"]
messages.head()
# Out:
#   label  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                   text
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1                                                                        Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3                                                    U dun say so early hor... U c already then say...
# 4                                        Nah I don't think he goes to usf, he lives around here though

# %%
# Clean data using the built in cleaner in gensim
messages['text_clean'] = messages['text'].apply(lambda x:gensim.utils.simple_preprocess(x))
messages.head()
# Out:
#   label  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                   text  \
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1                                                                        Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3                                                    U dun say so early hor... U c already then say...
# 4                                        Nah I don't think he goes to usf, he lives around here though
#
#                                                                                             text_clean
# 0  [go, until, jurong, point, crazy, available, only, in, bugis, great, world, la, buffet, cine, th...
# 1                                                                          [ok, lar, joking, wif, oni]
# 2  [free, entry, in, wkly, comp, to, win, fa, cup, final, tkts, st, may, text, fa, to, to, receive,...
# 3                                                       [dun, say, so, early, hor, already, then, say]
# 4                                [nah, don, think, he, goes, to, usf, he, lives, around, here, though]

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(messages['text_clean'],
                                                    messages['label'], test_size=0.2)

# %%
# Train the word2vec model
w2v_model = gensim.models.Word2Vec(X_train,         # Training data for the Word2Vec model
                                  vector_size=100,  # Dimensionality of the word vectors
                                  window=5,         # Maximum distance between the current and predicted word within a sentence
                                  min_count=2)      # Ignores all words with a total frequency lower than this

# %%
# Explore the word vector for "king" base on our trained model
w2v_model.wv['king']
# Out:
# array([-0.03570467,  0.06272582,  0.01334739,  0.01283974,  0.00729148,
#        -0.0999951 ,  0.04510066,  0.14050049, -0.05981153, -0.06371787,
#        -0.02452814, -0.11130314, -0.00720558,  0.03077019,  0.00361437,
#        -0.03360223,  0.03364979, -0.07396425, -0.03913377, -0.14615434,
#         0.04541676,  0.02940973,  0.04646965, -0.05054672, -0.03402423,
#        -0.01335635, -0.03123688, -0.04775636, -0.04388335,  0.00623232,
#         0.08424723,  0.02730883,  0.03850055, -0.06609036, -0.03614746,
#         0.06910188, -0.00429381, -0.07334486, -0.03180521, -0.09929204,
#        -0.01158667, -0.05319798, -0.0300455 ,  0.03252953,  0.05778084,
#        -0.03945362, -0.03331699, -0.01110804,  0.02960597,  0.07169679,
#         0.03247268, -0.0454764 , -0.01925392, -0.02033678, -0.03748275,
#         0.0602572 ,  0.03993828,  0.01774291, -0.08836221,  0.03714359,
#         0.01047315,  0.01173347, -0.01178514, -0.00849021, -0.09196077,
#         0.07148632,  0.03529032,  0.0519584 , -0.07264195,  0.10922771,
#        -0.0328727 ,  0.00351874,  0.08578123, -0.03399863,  0.06364159,
#         0.03531759,  0.00808899,  0.00339828, -0.0831503 ,  0.01184768,
#        -0.05127724,  0.02548168, -0.07714397,  0.09553372, -0.02271698,
#         0.01326896,  0.01403208,  0.06626806,  0.10135696,  0.03566165,
#         0.0965442 , -0.00208794,  0.01873145, -0.00688985,  0.10871294,
#         0.05846124,  0.05310002, -0.06901943,  0.04423312, -0.01256719],
#       dtype=float32)

# %%
# Find the most similar words to "king" based on word vectors from our trained model
w2v_model.wv.most_similar('king')
# Out:
# [('live', 0.9951883554458618),
#  ('holiday', 0.9951819181442261),
#  ('xmas', 0.9951316714286804),
#  ('every', 0.9951019287109375),
#  ('http', 0.9950454235076904),
#  ('has', 0.9950419664382935),
#  ('msg', 0.995025098323822),
#  ('chat', 0.994998037815094),
#  ('buy', 0.9949895143508911),
#  ('music', 0.9949892163276672)]

# %% [markdown]
# ## word2vec: How To Prep Word Vectors For Modeling

# %% [markdown]
# #### Train Our Own Model

# %%
# Read in the data, clean it, split it into train and test sets, and then train a word2vec model
import gensim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', 100)


messages = pd.read_csv('data/spam.csv', encoding='latin-1')
messages = messages.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)
messages.columns = ["label", "text"]



messages['text_clean'] = messages['text'].apply(lambda x: gensim.utils.simple_preprocess(x))
X_train, X_test, y_train, y_test = train_test_split(messages['text_clean'],
                                                    messages['label'], test_size=0.2)


w2v_model = gensim.models.Word2Vec(X_train,
                                   vector_size=100,
                                   window=5,
                                   min_count=2)

# %% [markdown]
# #### Prep Word Vectors

# %%
# Generate a list of words the word2vec model learned word vectors for
words_list = w2v_model.wv.index_to_key
print(words_list)
# Out:
# ['you', 'to', 'the', 'and', 'in', 'is', 'my', 'me', 'it', 'for', 'your', 'of', 'call', 'that', 'have', 'on', 'now', 'are', 'can', 'so', 'do', 'or', 'not', 'we', 'at', 'but', 'get', 'just', 'if', 'be', 'ur', 'will', 'with', 'no', 'this', 'when', 'how', 'up', 'gt', 'lt', 'free', 'what', 'from', 'go', 'out', 'll', 'all', 'ok', 'good', 'day', 'then', 'am', 'know', 'like', 'got', 'come', 'its', 'there', 'only', 'love', 'he', 'was', 'time', 'send', 'text', 'want', 'txt', 'going', 'home', 'stop', 'need', 'as', 'about', 'lor', 'see', 'by', 'still', 'da', 'she', 'today', 'sorry', 'don', 'one', 'mobile', 'did', 'reply', 'hi', 'back', 'our', 'dont', 'new', 'any', 'tell', 'take', 'her', 'week', 'they', 'dear', 'pls', 'phone', 'here', 'please', 'been', 'some', 'later', 'think', 'an', 'happy', 'night', 'where', 'msg', 'hey', 'claim', 'oh', 're', 'well', 'much', 'had', 'hope', 'great', 'message', 'too', 'work', 'has', 'more', 'wat', 'ì_', 'way', 'www', 'him', 'prize', 'make', 'right', 'give', 'who', 'should', 'won', 'number', 'yes', 'already', 'said', 'tomorrow', 've', 'doing', 'really', 'im', 'meet', 'yeah', 'find', 'amp', 'them', 'very', 'say', 'after', 'cash', 'win', 'morning', 'thanks', 'every', 'ask', 'last', 'why', 'babe', 'miss', 'let', 'lol', 'nokia', 'sent', 'cos', 'urgent', 'anything', 'life', 'cant', 'contact', 'min', 'com', 'uk', 'pick', 'buy', 'care', 'feel', 'keep', 'over', 'first', 'also', 'something', 'wait', 'many', 'mins', 'sure', 'thing', 'again', 'someone', 'would', 'even', 'tone', 'nice', 'money', 'before', 'sleep', 'chat', 'us', 'co', 'next', 'around', 'could', 'off', 'service', 'soon', 'box', 'his', 'ya', 'down', 'st', 'place', 'friend', 'things', 'which', 'help', 'sms', 'always', 'heart', 'fine', 'were', 'customer', 'late', 'tonight', 'went', 'friends', 'gud', 'gonna', 'told', 'wan', 'waiting', 'per', 'ìï', 'pm', 'leave', 'guaranteed', 'wish', 'haha', 'use', 'yet', 'thk', 'dun', 'same', 'other', 'year', 'people', 'name', 'getting', 'coming', 'try', 'man', 'holiday', 'days', 'ppm', 'stuff', 'meeting', 'done', 'better', 'class', 'th', 'talk', 'best', 'hello', 'trying', 'didn', 'lunch', 'may', 'thought', 'end', 'pobox', 'mind', 'finish', 'job', 'special', 'draw', 'being', 'yup', 'bit', 'god', 'lot', 'smile', 'enjoy', 'thats', 'ill', 'cs', 'real', 'line', 'house', 'eat', 'wk', 'into', 'person', 'check', 'camera', 'awarded', 'receive', 'yo', 'ready', 'never', 'cool', 'latest', 'live', 'having', 'chance', 'few', 'guys', 'half', 'birthday', 'dinner', 'than', 'hrs', 'liao', 'play', 'long', 'guess', 'another', 'shows', 'problem', 'month', 'wanna', 'dat', 'quite', 'once', 'early', 'watching', 'world', 'forgot', 'reach', 'word', 'tv', 'car', 'video', 'shit', 'luv', 'sir', 'tones', 'pa', 'little', 'probably', 'bt', 'start', 'offer', 'because', 'maybe', 'bad', 'sweet', 'kiss', 'nothing', 'shopping', 'lar', 'wont', 'nd', 'watch', 'bed', 'shall', 'big', 'part', 'left', 'landline', 'ringtone', 'xx', 'den', 'xxx', 'code', 'pay', 'sexy', 'jus', 'sat', 'princess', 'baby', 'room', 'weekend', 'account', 'hour', 'cost', 'office', 'rate', 'easy', 'didnt', 'po', 'girl', 'might', 'remember', 'made', 'wife', 'asked', 'selected', 'ever', 'texts', 'calls', 'called', 'orange', 'afternoon', 'plan', 'speak', 'nite', 'thank', 'looking', 'minutes', 'between', 'goes', 'apply', 'dis', 'two', 'does', 'thanx', 'award', 'working', 'entry', 'face', 'missed', 'fun', 'valid', 'put', 'hear', 'aight', 'enough', 'okay', 'de', 'those', 'tmr', 'leh', 'must', 'came', 'times', 'ah', 'wake', 'without', 'dunno', 'hav', 'collect', 'dad', 'optout', 'pain', 'havent', 'attempt', 'age', 'everything', 'net', 'colour', 'price', 'til', 'important', 'join', 'bus', 'network', 'these', 'most', 'means', 'online', 'making', 'missing', 'alright', 'words', 'wot', 'weekly', 'gift', 'oso', 'true', 'actually', 'though', 'show', 'school', 'wanted', 'able', 'xmas', 'update', 'years', 'until', 'plz', 'says', 'beautiful', 'bring', 'while', 'plus', 'evening', 'delivery', 'boy', 'order', 't ...

# %% [markdown]
# So what this represents is it represents all of the words that our Word2Vec model learned a vector for. Or put another way, it's all of the words that appeared in the training data at least twice. So you can explore these words if you'd like.

# %%
# Generate aggregated sentence vectors based on the word vectors for each word in the sentence
def average_word_vectors(sentence, model):
    
    # Filter out words not in the model's vocabulary
    words = [model.wv[word] for word in sentence if word in model.wv.index_to_key]
    if len(words) == 0:
        return np.zeros(model.vector_size)  # Return a zero vector if no words are in the vocabulary
        
    return np.mean(words, axis=0)           # Average the vectors

# Create sentence vectors for each sentence in X_test
w2v_vect = np.array([average_word_vectors(ls, w2v_model) for ls in X_test])

# %% [markdown]
# We're using lists comprehension to cycle through each text message in the test set. So the text message is represented by LS. This is a list of words. So this LS within this nested list comprehension, then we're cycling through each word in that text message. So again, each word is represented by i. And what we're doing for each word is we're telling the fit Word2Vec model to return the word vector for each word in the text message. And we're applying one condition. We're saying only try to return that word vector as long as that word vector was learned by the model. If we don't apply that condition, then the Word2Vec model might try to find a word vector for a word it never learned, and it will return an error. We'll have is a nested set of arrays within an array.

# %% [markdown]
# We're going to print the length of the original text message. So say X_test, and then we'll say find the location of that text message using the index. That's what iloc does. So I'll say pass in the index. So again, now we have the length of the original text message.

# %%
messages.head()
# Out:
#   label  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                   text  \
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1                                                                        Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3                                                    U dun say so early hor... U c already then say...
# 4                                        Nah I don't think he goes to usf, he lives around here though
#
#                                                                                             text_clean
# 0  [go, until, jurong, point, crazy, available, only, in, bugis, great, world, la, buffet, cine, th...
# 1                                                                          [ok, lar, joking, wif, oni]
# 2  [free, entry, in, wkly, comp, to, win, fa, cup, final, tkts, st, may, text, fa, to, to, receive,...
# 3                                                       [dun, say, so, early, hor, already, then, say]
# 4                                [nah, don, think, he, goes, to, usf, he, lives, around, here, though]

# %%
# Why is the length of the sentence different than the length of the sentence vector?

for i,v in enumerate(w2v_vect):
    print(len(X_test.iloc[i]), len(v))
# Out:
# 17 100
# 5 100
# 6 100
# 5 100
# 23 100
# 10 100
# 12 100
# 4 100
# 23 100
# 4 100
# 13 100
# 24 100
# 6 100
# 11 100
# 26 100
# 11 100
# 18 100
# 9 100
# 10 100
# 6 100
# 9 100
# 14 100
# 6 100
# 7 100
# 10 100
# 9 100
# 29 100
# 5 100
# 13 100
# 6 100
# 29 100
# 52 100
# 9 100
# 22 100
# 10 100
# 5 100
# 86 100
# 5 100
# 26 100
# 5 100
# 15 100
# 9 100
# 6 100
# 21 100
# 12 100
# 8 100
# 8 100
# 5 100
# 5 100
# 10 100
# 25 100
# 5 100
# 11 100
# 21 100
# 10 100
# 10 100
# 6 100
# 6 100
# 12 100
# 4 100
# 24 100
# 6 100
# 11 100
# 5 100
# 5 100
# 9 100
# 16 100
# 23 100
# 9 100
# 10 100
# 7 100
# 5 100
# 5 100
# 25 100
# 3 100
# 12 100
# 7 100
# 16 100
# 60 100
# 30 100
# 23 100
# 6 100
# 17 100
# 12 100
# 4 100
# 5 100
# 19 100
# 1 100
# 4 100
# 9 100
# 26 100
# 14 100
# 22 100
# 11 100
# 6 100
# 11 100
# 11 100
# 5 100
# 5 100
# 5 100
# 21 100
# 30 100
# 17 100
# 6 100
# 16 100
# 6 100
# 11 100
# 11 100
# 9 100
# 7 100
# 8 100
# 8 100
# 15 100
# 10 100
# 9 100
# 6 100
# 33 100
# 16 100
# 5 100
# 8 100
# 1 100
# 10 100
# 18 100
# 7 100
# 31 100
# 7 100
# 23 100
# 23 100
# 9 100
# 20 100
# 15 100
# 5 100
# 6 100
# 23 100
# 10 100
# 17 100
# 17 100
# 16 100
# 9 100
# 4 100
# 20 100
# 5 100
# 3 100
# 20 100
# 4 100
# 6 100
# 21 100
# 6 100
# 19 100
# 14 100
# 16 100
# 12 100
# 8 100
# 28 100
# 4 100
# 8 100
# 6 100
# 6 100
# 1 100
# 11 100
# 27 100
# 5 100
# 28 100
# 27 100
# 22 100
# 25 100
# 16 100
# 23 100
# 6 100
# 18 100
# 6 100
# 26 100
# 24 100
# 12 100
# 7 100
# 4 100
# 9 100
# 14 100
# 5 100
# 18 100
# 5 100
# 24 100
# 5 100
# 9 100
# 7 100
# 4 100
# 9 100
# 7 100
# 22 100
# 20 100
# 5 100
# 6 100
# 13 100
# 25 100
# 16 100
# 25 100
# 4 100
# 3 100
# 5 100
# 36 100
# 3 100
# 9 100
# 17 100
# 27 100
# 8 100
# 26 100
# 10 100
# 5 100
# 8 100
# 8 100
# 13 100
# 16 100
# 7 100
# 7 100
# 6 100
# 6 100
# 11 100
# 1 100
# 5 100
# 13 100
# 21 100
# 6 100
# 16 100
# 5 100
# 4 100
# 12 100
# 5 100
# 21 100
# 5 100
# 9 100
# 13 100
# 8 100
# 16 100
# 9 100
# 26 100
# 9 100
# 31 100
# 7 100
# 9 100
# 10 100
# 16 100
# 9 100
# 18 100
# 5 100
# 18 100
# 9 100
# 7 100
# 6 100
# 24 100
# 11 100
# 12 100
# 9 100
# 5 100
# 6 100
# 9 100
# 8 100
# 24 100
# 9 100
# 6 100
# 26 100
# 7 100
# 7 100
# 70 100
# 5 100
# 15 100
# 13 100
# 10 100
# 21 100
# 4 100
# 26 100
# 11 100
# 8 100
# 7 100
# 25 100
# 15 100
# 20 100
# 6 100
# 6 100
# 10 100
# 21 100
# 30 100
# 20 100
# 18 100
# 11 100
# 19 100
# 9 100
# 6 100
# 6 100
# 14 100
# 5 100
# 23 100
# 5 100
# 14 100
# 37 100
# 4 100
# 23 100
# 28 100
# 9 100
# 3 100
# 22 100
# 13 100
# 13 100
# 31 100
# 35 100
# 17 100
# 9 100
# 6 100
# 13 100
# 8 100
# 37 100
# 7 100
# 12 100
# 23 100
# 23 100
# 16 100
# 8 100
# 8 100
# 17 100
# 9 100
# 3 100
# 16 100
# 12 100
# 7 100
# 11 100
# 22 100
# 10 100
# 42 100
# 6 100
# 9 100
# 22 100
# 22 100
# 22 100
# 7 100
# 8 100
# 7 100
# 21 100
# 12 100
# 15 100
# 8 100
# 17 100
# 26 100
# 5 100
# 13 100
# 4 100
# 20 100
# 10 100
# 4 100
# 4 100
# 15 100
# 17 100
# 14 100
# 6 100
# 4 100
# 10 100
# 17 100
# 14 100
# 10 100
# 5 100
# 10 100
# 6 100
# 28 100
# 10 100
# 11 100
# 15 100
# 5 100
# 17 100
# 9 100
# 19 100
# 34 100
# 8 100
# 7 100
# 19 100
# 14 100
# 13 100
# 8 100
# 8 100
# 13 100
# 29 100
# 16 100
# 8 100
# 5 100
# 22 100
# 5 100
# 58 100
# 9 100
# 28 100
# 13 100
# 3 100
# 27 100
# 16 100
# 4 100
# 12 100
# 28 100
# 4 100
# 16 100
# 31 100
# 24 100
# 6 100
# 31 100
# 18 100
# 8 100
# 21 100
# 9 100
# 28 100
# 5 100
# 16 100
# 8 100
# 15 100
# 6 100
# 9 100
# 5 100
# 12 100
# 10 100
# 22 100
# 19 100
# 13 100
# 13 100
# 6 100
# 20 100
# 16 100
# 14 100
# 30 100
# 6 100
# 23 100
# 14 100
# 8 100
# 15 100
# 10 100
# 26 100
# 8 100
# 7 100
# 4 100
# 7 100
# 38 100
# 12 100
# 8 100
# 7 100
# 7 100
# 4 100
# 11 100
# 6 100
# 9 100
# 5 100
# 4 100
# 8 100
# 21 100
# 35 100
# 27 100
# 14 100
# 7 100
# 11 100
# 19 100
# 12 100
# 20 100
# 11 100
# 12 100
# 45 100
# 8 100
# 15 100
# 4 100
# 22 100
# 6 100
# 79 100
# 12 100
# 28 100
# 5 100
# 13 100
# 26 100
# 11 100
# 29 100
# 12 100
# 26 100
# 28 100
# 7 100
# 27 100
# 11 100
# 25 100
# 6 100
# 24 100
# 9 100
# 4 100
# 24 100
# 9 100
# 13 100
# 36 100
# 18 100
# 10 100
# 11 100
# 25 100
# 25 100
# 30 100
# 16 100
# 27 100
# 8 100
# 27 100
# 11 100
# 7 100
# 18 100
# 25 100
# 6 100
# 5 100
# 21 100
# 18 100
# 8 100
# 49 100
# 13 100
# 6 100
# 8 100
# 12 100
# 8 100
# 16 100
# 27 100
# 1 100
# 24 100
# 1 100
# 56 100
# 4 100
# 4 100
# 20 100
# 4 100
# 9 100
# 6 100
# 14 100
# 41 100
# 46 100
# 8 100
# 15 100
# 22 100
# 7 100
# 12 100
# 12 100
# 23 100
# 9 100
# 21 100
# 6 100
# 27 100
# 30 100
# 7 100
# 21 100
# 9 100
# 6 100
# 14 100
# 33 100
# 24 100
# 6 100
# 9 100
# 9 100
# 22 100
# 26 100
# 22 100
# 6 100
# 5 100
# 21 100
# 9 100
# 30 100
# 18 100
# 15 100
# 27 100
# 6 100
# 15 100
# 6 100
# 23 100
# 22 100
# 23 100
# 5 100
# 9 100
# 18 100
# 7 100
# 19 100
# 5 100
# 6 100
# 9 100
# 18 100
# 8 100
# 31 100
# 1 100
# 15 100
# 17 100
# 30 100
# 25 100
# 11 100
# 6 100
# 11 100
# 9 100
# 17 100
# 30 100
# 4 100
# 14 100
# 19 100
# 9 100
# 3 100
# 3 100
# 6 100
# 4 100
# 23 100
# 23 100
# 11 100
# 9 100
# 4 100
# 44 100
# 20 100
# 7 100
# 24 100
# 7 100
# 8 100
# 7 100
# 15 100
# 14 100
# 25 100
# 8 100
# 12 100
# 7 100
# 27 100
# 13 100
# 8 100
# 8 100
# 6 100
# 30 100
# 9 100
# 8 100
# 4 100
# 15 100
# 13 100
# 7 100
# 7 100
# 16 100
# 8 100
# 19 100
# 15 100
# 6 100
# 16 100
# 17 100
# 12 100
# 7 100
# 11 100
# 24 100
# 30 100
# 23 100
# 21 100
# 52 100
# 15 100
# 4 100
# 42 100
# 5 100
# 8 100
# 27 100
# 24 100
# 29 100
# 13 100
# 23 100
# 22 100
# 7 100
# 5 100
# 42 100
# 6 100
# 21 100
# 3 100
# 7 100
# 18 100
# 14 100
# 20 100
# 6 100
# 5 100
# 3 100
# 30 100
# 17 100
# 27 100
# 5 100
# 10 100
# 5 100
# 8 100
# 18 100
# 24 100
# 41 100
# 5 100
# 7 100
# 20 100
# 37 100
# 13 100
# 16 100
# 9 100
# 5 100
# 25 100
# 8 100
# 17 100
# 16 100
# 28 100
# 15 100
# 4 100
# 13 100
# 10 100
# 5 100
# 23 100
# 21 100
# 5 100
# 4 100
# 10 100
# 16 100
# 24 100
# 8 100
# 6 100
# 14 100
# 12 100
# 15 100
# 9 100
# 3 100
# 8 100
# 8 100
# 13 100
# 21 100
# 13 100
# 9 100
# 12 100
# 5 100
# 25 100
# 5 100
# 3 100
# 5 100
# 17 100
# 24 100
# 22 100
# 7 100
# 30 100
# 31 100
# 9 100
# 17 100
# 9 100
# 5 100
# 12 100
# 24 100
# 9 100
# 6 100
# 6 100
# 9 100
# 7 100
# 17 100
# 11 100
# 15 100
# 17 100
# 4 100
# 6 100
# 22 100
# 6 100
# 10 100
# 7 100
# 22 100
# 8 100
# 44 100
# 21 100
# 7 100
# 18 100
# 30 100
# 9 100
# 8 100
# 15 100
# 14 100
# 10 100
# 8 100
# 21 100
# 24 100
# 14 100
# 22 100
# 8 100
# 49 100
# 3 100
# 29 100
# 7 100
# 12 100
# 19 100
# 16 100
# 21 100
# 19 100
# 27 100
# 12 100
# 7 100
# 21 100
# 25 100
# 7 100
# 20 100
# 5 100
# 15 100
# 13 100
# 20 100
# 11 100
# 20 100
# 6 100
# 29 100
# 11 100
# 23 100
# 31 100
# 4 100
# 7 100
# 7 100
# 6 100
# 8 100
# 12 100
# 14 100
# 27 100
# 13 100
# 11 100
# 6 100
# 9 100
# 13 100
# 9 100
# 3 100
# 14 100
# 5 100
# 60 100
# 27 100
# 4 100
# 4 100
# 9 100
# 7 100
# 45 100
# 26 100
# 12 100
# 12 100
# 26 100
# 21 100
# 6 100
# 17 100
# 22 100
# 4 100
# 8 100
# 8 100
# 14 100
# 17 100
# 23 100
# 6 100
# 15 100
# 6 100
# 4 100
# 26 100
# 21 100
# 8 100
# 22 100
# 5 100
# 4 100
# 14 100
# 19 100
# 21 100
# 10 100
# 21 100
# 17 100
# 22 100
# 19 100
# 9 100
# 15 100
# 27 100
# 9 100
# 5 100
# 17 100
# 19 100
# 24 100
# 6 100
# 5 100
# 17 100
# 8 100
# 11 100
# 8 100
# 1 100
# 19 100
# 13 100
# 8 100
# 14 100
# 6 100
# 4 100
# 6 100
# 23 100
# 18 100
# 5 100
# 13 100
# 7 100
# 33 100
# 10 100
# 21 100
# 5 100
# 21 100
# 21 100
# 12 100
# 5 100
# 10 100
# 17 100
# 14 100
# 9 100
# 2 100
# 7 100
# 3 100
# 4 100
# 11 100
# 5 100
# 11 100
# 4 100
# 11 100
# 28 100
# 20 100
# 6 100
# 18 100
# 29 100
# 3 100
# 15 100
# 23 100
# 11 100
# 4 100
# 4 100
# 9 100
# 17 100
# 6 100
# 9 100
# 6 100
# 51 100
# 20 100
# 38 100
# 23 100
# 24 100
# 24 100
# 31 100
# 22 100
# 5 100
# 33 100
# 17 100
# 23 100
# 4 100
# 30 100
# 17 100
# 4 100
# 25 100
# 6 100
# 28 100
# 12 100
# 11 100
# 2 100
# 28 100
# 7 100
# 10 100
# 10 100
# 25 100
# 5 100
# 15 100
# 23 100
# 5 100
# 8 100
# 8 100
# 6 100
# 30 100
# 11 100
# 13 100
# 5 100
# 25 100
# 25 100
# 13 100
# 21 100
# 7 100
# 6 100
# 25 100
# 6 100
# 22 100
# 5 100
# 20 100
# 6 100
# 11 100
# 24 100
# 6 100
# 9 100
# 16 100
# 24 100
# 15 100
# 6 100
# 7 100
# 21 100
# 7 100
# 25 100
# 17 100
# 14 100
# 15 100
# 9 100
# 17 100
# 9 100
# 8 100
# 1 100
# 21 100
# 6 100
# 7 100
# 15 100
# 8 100
# 32 100
# 26 100
# 10 100
# 9 100
# 21 100
# 25 100
# 23 100
# 7 100
# 8 100
# 9 100
# 14 100
# 21 100
# 26 100
# 7 100
# 5 100
# 4 100
# 6 100
# 7 100
# 8 100
# 5 100
# 13 100
# 6 100
# 7 100
# 9 100
# 11 100
# 26 100
# 11 100
# 28 100
# 8 100
# 10 100
# 6 100
# 22 100
# 4 100
# 42 100
# 3 100
# 20 100
# 8 100
# 8 100
# 26 100
# 24 100
# 7 100
# 2 100
# 20 100
# 5 100
# 16 100
# 29 100
# 19 100
# 5 100
# 29 100
# 6 100
# 3 100
# 20 100
# 2 100
# 21 100
# 5 100
# 25 100
# 10 100
# 3 100
# 23 100
# 9 100
# 15 100
# 18 100
# 30 100
# 28 100
# 11 100
# 16 100
# 5 100
# 46 100
# 27 100
# 1 100
# 77 100
# 31 100
# 14 100
# 110 100
# 5 100
# 17 100
# 19 100
# 9 100
# 14 100
# 9 100
# 6 100
# 29 100
# 5 100
# 19 100
# 5 100
# 22 100
# 6 100
# 16 100
# 9 100
# 25 100
# 10 100
# 21 100
# 5 100
# 5 100
# 8 100
# 10 100
# 8 100
# 11 100
# 21 100
# 21 100
# 2 100
# 21 100
# 24 100
# 22 100
# 24 100
# 6 100
# 12 100
# 23 100
# 5 100
# 6 100
# 9 100
# 11 100
# 13 100
# 8 100
# 30 100
# 6 100
# 7 100
# 6 100
# 29 100
# 5 100
# 8 100
# 6 100
# 7 100
# 5 100
# 6 100
# 15 100
# 8 100
# 4 100
# 5 100
# 1 100

# %%
# Compute sentence vectors by averaging the word vectors for the words contained in the sentence
w2v_vect_avg = []

for vect in w2v_vect:
    if len(vect) > 0:                # Check if vect is not empty
        vect_array = np.array(vect)  # Ensure vect is a 2D array
        if vect_array.ndim == 1:
            # If vect_array is 1D, convert it to 2D with one row
            vect_array = vect_array.reshape(1, -1)
        vect_avg = np.mean(vect_array, axis=0)  # Compute the mean vector
        w2v_vect_avg.append(vect_avg)           # Append the averaged vector
    else:
        # Handle the case where vect is empty (no words in sentence)
        w2v_vect_avg.append(np.zeros(w2v_model.vector_size))  # Append a zero vector

# Verify consistency of sentence vector lengths
for i, v in enumerate(w2v_vect_avg):
    print(f"Sentence {i}: Length of sentence = {len(X_test.iloc[i])}, Length of vector = {len(v)}")  # Print lengths of sentence and vector
# Out:
# Sentence 0: Length of sentence = 17, Length of vector = 100
# Sentence 1: Length of sentence = 5, Length of vector = 100
# Sentence 2: Length of sentence = 6, Length of vector = 100
# Sentence 3: Length of sentence = 5, Length of vector = 100
# Sentence 4: Length of sentence = 23, Length of vector = 100
# Sentence 5: Length of sentence = 10, Length of vector = 100
# Sentence 6: Length of sentence = 12, Length of vector = 100
# Sentence 7: Length of sentence = 4, Length of vector = 100
# Sentence 8: Length of sentence = 23, Length of vector = 100
# Sentence 9: Length of sentence = 4, Length of vector = 100
# Sentence 10: Length of sentence = 13, Length of vector = 100
# Sentence 11: Length of sentence = 24, Length of vector = 100
# Sentence 12: Length of sentence = 6, Length of vector = 100
# Sentence 13: Length of sentence = 11, Length of vector = 100
# Sentence 14: Length of sentence = 26, Length of vector = 100
# Sentence 15: Length of sentence = 11, Length of vector = 100
# Sentence 16: Length of sentence = 18, Length of vector = 100
# Sentence 17: Length of sentence = 9, Length of vector = 100
# Sentence 18: Length of sentence = 10, Length of vector = 100
# Sentence 19: Length of sentence = 6, Length of vector = 100
# Sentence 20: Length of sentence = 9, Length of vector = 100
# Sentence 21: Length of sentence = 14, Length of vector = 100
# Sentence 22: Length of sentence = 6, Length of vector = 100
# Sentence 23: Length of sentence = 7, Length of vector = 100
# Sentence 24: Length of sentence = 10, Length of vector = 100
# Sentence 25: Length of sentence = 9, Length of vector = 100
# Sentence 26: Length of sentence = 29, Length of vector = 100
# Sentence 27: Length of sentence = 5, Length of vector = 100
# Sentence 28: Length of sentence = 13, Length of vector = 100
# Sentence 29: Length of sentence = 6, Length of vector = 100
# Sentence 30: Length of sentence = 29, Length of vector = 100
# Sentence 31: Length of sentence = 52, Length of vector = 100
# Sentence 32: Length of sentence = 9, Length of vector = 100
# Sentence 33: Length of sentence = 22, Length of vector = 100
# Sentence 34: Length of sentence = 10, Length of vector = 100
# Sentence 35: Length of sentence = 5, Length of vector = 100
# Sentence 36: Length of sentence = 86, Length of vector = 100
# Sentence 37: Length of sentence = 5, Length of vector = 100
# Sentence 38: Length of sentence = 26, Length of vector = 100
# Sentence 39: Length of sentence = 5, Length of vector = 100
# Sentence 40: Length of sentence = 15, Length of vector = 100
# Sentence 41: Length of sentence = 9, Length of vector = 100
# Sentence 42: Length of sentence = 6, Length of vector = 100
# Sentence 43: Length of sentence = 21, Length of vector = 100
# Sentence 44: Length of sentence = 12, Length of vector = 100
# Sentence 45: Length of sentence = 8, Length of vector = 100
# Sentence 46: Length of sentence = 8, Length of vector = 100
# Sentence 47: Length of sentence = 5, Length of vector = 100
# Sentence 48: Length of sentence = 5, Length of vector = 100
# Sentence 49: Length of sentence = 10, Length of vector = 100
# Sentence 50: Length of sentence = 25, Length of vector = 100
# Sentence 51: Length of sentence = 5, Length of vector = 100
# Sentence 52: Length of sentence = 11, Length of vector = 100
# Sentence 53: Length of sentence = 21, Length of vector = 100
# Sentence 54: Length of sentence = 10, Length of vector = 100
# Sentence 55: Length of sentence = 10, Length of vector = 100
# Sentence 56: Length of sentence = 6, Length of vector = 100
# Sentence 57: Length of sentence = 6, Length of vector = 100
# Sentence 58: Length of sentence = 12, Length of vector = 100
# Sentence 59: Length of sentence = 4, Length of vector = 100
# Sentence 60: Length of sentence = 24, Length of vector = 100
# Sentence 61: Length of sentence = 6, Length of vector = 100
# Sentence 62: Length of sentence = 11, Length of vector = 100
# Sentence 63: Length of sentence = 5, Length of vector = 100
# Sentence 64: Length of sentence = 5, Length of vector = 100
# Sentence 65: Length of sentence = 9, Length of vector = 100
# Sentence 66: Length of sentence = 16, Length of vector = 100
# Sentence 67: Length of sentence = 23, Length of vector = 100
# Sentence 68: Length of sentence = 9, Length of vector = 100
# Sentence 69: Length of sentence = 10, Length of vector = 100
# Sentence 70: Length of sentence = 7, Length of vector = 100
# Sentence 71: Length of sentence = 5, Length of vector = 100
# Sentence 72: Length of sentence = 5, Length of vector = 100
# Sentence 73: Length of sentence = 25, Length of vector = 100
# Sentence 74: Length of sentence = 3, Length of vector = 100
# Sentence 75: Length of sentence = 12, Length of vector = 100
# Sentence 76: Length of sentence = 7, Length of vector = 100
# Sentence 77: Length of sentence = 16, Length of vector = 100
# Sentence 78: Length of sentence = 60, Length of vector = 100
# Sentence 79: Length of sentence = 30, Length of vector = 100
# Sentence 80: Length of sentence = 23, Length of vector = 100
# Sentence 81: Length of sentence = 6, Length of vector = 100
# Sentence 82: Length of sentence = 17, Length of vector = 100
# Sentence 83: Length of sentence = 12, Length of vector = 100
# Sentence 84: Length of sentence = 4, Length of vector = 100
# Sentence 85: Length of sentence = 5, Length of vector = 100
# Sentence 86: Length of sentence = 19, Length of vector = 100
# Sentence 87: Length of sentence = 1, Length of vector = 100
# Sentence 88: Length of sentence = 4, Length of vector = 100
# Sentence 89: Length of sentence = 9, Length of vector = 100
# Sentence 90: Length of sentence = 26, Length of vector = 100
# Sentence 91: Length of sentence = 14, Length of vector = 100
# Sentence 92: Length of sentence = 22, Length of vector = 100
# Sentence 93: Length of sentence = 11, Length of vector = 100
# Sentence 94: Length of sentence = 6, Length of vector = 100
# Sentence 95: Length of sentence = 11, Length of vector = 100
# Sentence 96: Length of sentence = 11, Length of vector = 100
# Sentence 97: Length of sentence = 5, Length of vector = 100
# Sentence 98: Length of sentence = 5, Length of vector = 100
# Sentence 99: Length of sentence = 5, Length of vector = 100
# Sentence 100: Length of sentence = 21, Length of vector = 100
# Sentence 101: Length of sentence = 30, Length of vector = 100
# Sentence 102: Length of sentence = 17, Length of vector = 100
# Sentence 103: Length of sentence = 6, Length of vector = 100
# Sentence 104: Length of sentence = 16, Length of vector = 100
# Sentence 105: Length of sentence = 6, Length of vector = 100
# Sentence 106: Length of sentence = 11, Length of vector = 100
# Sentence 107: Length of sentence = 11, Length of vector = 100
# Sentence 108: Length of sentence = 9, Length of vector = 100
# Sentence 109: Length of sentence = 7, Length of vector = 100
# Sentence 110: Length of sentence = 8, Length of vector = 100
# Sentence 111: Length of sentence = 8, Length of vector = 100
# Sentence 112: Length of sentence = 15, Length of vector = 100
# Sentence 113: Length of sentence = 10, Length of vector = 100
# Sentence 114: Length of sentence = 9, Length of vector = 100
# Sentence 115: Length of sentence = 6, Length of vector = 100
# Sentence 116: Length of sentence = 33, Length of vector = 100
# Sentence 117: Length of sentence = 16, Length of vector = 100
# Sentence 118: Length of sentence = 5, Length of vector = 100
# Sentence 119: Length of sentence = 8, Length of vector = 100
# Sentence 120: Length of sentence = 1, Length of vector = 100
# Sentence 121: Length of sentence = 10, Length of vector = 100
# Sentence 122: Length of sentence = 18, Length of vector = 100
# Sentence 123: Length of sentence = 7, Length of vector = 100
# Sentence 124: Length of sentence = 31, Length of vector = 100
# Sentence 125: Length of sentence = 7, Length of vector = 100
# Sentence 126: Length of sentence = 23, Length of vector = 100
# Sentence 127: Length of sentence = 23, Length of vector = 100
# Sentence 128: Length of sentence = 9, Length of vector = 100
# Sentence 129: Length of sentence = 20, Length of vector = 100
# Sentence 130: Length of sentence = 15, Length of vector = 100
# Sentence 131: Length of sentence = 5, Length of vector = 100
# Sentence 132: Length of sentence = 6, Length of vector = 100
# Sentence 133: Length of sentence = 23, Length of vector = 100
# Sentence 134: Length of sentence = 10, Length of vector = 100
# Sentence 135: Length of sentence = 17, Length of vector = 100
# Sentence 136: Length of sentence = 17, Length of vector = 100
# Sentence 137: Length of sentence = 16, Length of vector = 100
# Sentence 138: Length of sentence = 9, Length of vector = 100
# Sentence 139: Length of sentence = 4, Length of vector = 100
# Sentence 140: Length of sentence = 20, Length of vector = 100
# Sentence 141: Length of sentence = 5, Length of vector = 100
# Sentence 142: Length of sentence = 3, Length of vector = 100
# Sentence 143: Length of sentence = 20, Length of vector = 100
# Sentence 144: Length of sentence = 4, Length of vector = 100
# Sentence 145: Length of sentence = 6, Length of vector = 100
# Sentence 146: Length of sentence = 21, Length of vector = 100
# Sentence 147: Length of sentence = 6, Length of vector = 100
# Sentence 148: Length of sentence = 19, Length of vector = 100
# Sentence 149: Length of sentence = 14, Length of vector = 100
# Sentence 150: Length of sentence = 16, Length of vector = 100
# Sentence 151: Length of sentence = 12, Length of vector = 100
# Sentence 152: Length of sentence = 8, Length of vector = 100
# Sentence 153: Length of sentence = 28, Length of vector = 100
# Sentence 154: Length of sentence = 4, Length of vector = 100
# Sentence 155: Length of sentence = 8, Length of vector = 100
# Sentence 156: Length of sentence = 6, Length of vector = 100
# Sentence 157: Length of sentence = 6, Length of vector = 100
# Sentence 158: Length of sentence = 1, Length of vector = 100
# Sentence 159: Length of sentence = 11, Length of vector = 100
# Sentence 160: Length of sentence = 27, Length of vector = 100
# Sentence 161: Length of sentence = 5, Length of vector = 100
# Sentence 162: Length of sentence = 28, Length of vector = 100
# Sentence 163: Length of sentence = 27, Length of vector = 100
# Sentence 164: Length of sentence = 22, Length of vector = 100
# Sentence 165: Length of sentence = 25, Length of vector = 100
# Sentence 166: Length of sentence = 16, Length of vector = 100
# Sentence 167: Length of sentence = 23, Length of vector = 100
# Sentence 168: Length of sentence = 6, Length of vector = 100
# Sentence 169: Length of sentence = 18, Length of vector = 100
# Sentence 170: Length of sentence = 6, Length of vector = 100
# Sentence 171: Length of sentence = 26, Length of vector = 100
# Sentence 172: Length of sentence = 24, Length of vector = 100
# Sentence 173: Length of sentence = 12, Length of vector = 100
# Sentence 174: Length of sentence = 7, Length of vector = 100
# Sentence 175: Length of sentence = 4, Length of vector = 100
# Sentence 176: Length of sentence = 9, Length of vector = 100
# Sentence 177: Length of sentence = 14, Length of vector = 100
# Sentence 178: Length of sentence = 5, Length of vector = 100
# Sentence 179: Length of sentence = 18, Length of vector = 100
# Sentence 180: Length of sentence = 5, Length of vector = 100
# Sentence 181: Length of sentence = 24, Length of vector = 100
# Sentence 182: Length of sentence = 5, Length of vector = 100
# Sentence 183: Length of sentence = 9, Length of vector = 100
# Sentence 184: Length of sentence = 7, Length of vector = 100
# Sentence 185: Length of sentence = 4, Length of vector = 100
# Sentence 186: Length of sentence = 9, Length of vector = 100
# Sentence 187: Length of sentence = 7, Length of vector = 100
# Sentence 188: Length of sentence = 22, Length of vector = 100
# Sentence 189: Length of sentence = 20, Length of vector = 100
# Sentence 190: Length of sentence = 5, Length of vector = 100
# Sentence 191: Length of sentence = 6, Length of vector = 100
# Sentence 192: Length of sentence = 13, Length of vector = 100
# Sentence 193: Length of sentence = 25, Length of vector = 100
# Sentence 194: Length of sentence = 16, Length of vector = 100
# Sentence 195: Length of sentence = 25, Length of vector = 100
# Sentence 196: Length of sentence = 4, Length of vector = 100
# Sentence 197: Length of sentence = 3, Length of vector = 100
# Sentence 198: Length of sentence = 5, Length of vector = 100
# Sentence 199: Length of sentence = 36, Length of vector = 100
# Sentence 200: Length of sentence = 3, Length of vector = 100
# Sentence 201: Length of sentence = 9, Length of vector = 100
# Sentence 202: Length of sentence = 17, Length of vector = 100
# Sentence 203: Length of sentence = 27, Length of vector = 100
# Sentence 204: Length of sentence = 8, Length of vector = 100
# Sentence 205: Length of sentence = 26, Length of vector = 100
# Sentence 206: Length of sentence = 10, Length of vector = 100
# Sentence 207: Length of sentence = 5, Length of vector = 100
# Sentence 208: Length of sentence = 8, Length of vector = 100
# Sentence 209: Length of sentence = 8, Length of vector = 100
# Sentence 210: Length of sentence = 13, Length of vector = 100
# Sentence 211: Length of sentence = 16, Length of vector = 100
# Sentence 212: Length of sentence = 7, Length of vector = 100
# Sentence 213: Length of sentence = 7, Length of vector = 100
# Sentence 214: Length of sentence = 6, Length of vector = 100
# Sentence 215: Length of sentence = 6, Length of vector = 100
# Sentence 216: Length of sentence = 11, Length of vector = 100
# Sentence 217: Length of sentence = 1, Length of vector = 100
# Sentence 218: Length of sentence = 5, Length of vector = 100
# Sentence 219: Length of sentence = 13, Length of vector = 100
# Sentence 220: Length of sentence = 21, Length of vector = 100
# Sentence 221: Length of sentence = 6, Length of vector = 100
# Sentence 222: Length of sentence = 16, Length of vector = 100
# Sentence 223: Length of sentence = 5, Length of vector = 100
# Sentence 224: Length of sentence = 4, Length of vector = 100
# Sentence 225: Length of sentence = 12, Length of vector = 100
# Sentence 226: Length of sentence = 5, Length of vector = 100
# Sentence 227: Length of sentence = 21, Length of vector = 100
# Sentence 228: Length of sentence = 5, Length of vector = 100
# Sentence 229: Length of sentence = 9, Length of vector = 100
# Sentence 230: Length of sentence = 13, Length of vector = 100
# Sentence 231: Length of sentence = 8, Length of vector = 100
# Sentence 232: Length of sentence = 16, Length of vector = 100
# Sentence 233: Length of sentence = 9, Length of vector = 100
# Sentence 234: Length of sentence = 26, Length of vector = 100
# Sentence 235: Length of sentence = 9, Length of vector = 100
# Sentence 236: Length of sentence = 31, Length of vector = 100
# Sentence 237: Length of sentence = 7, Length of vector = 100
# Sentence 238: Length of sentence = 9, Length of vector = 100
# Sentence 239: Length of sentence = 10, Length of vector = 100
# Sentence 240: Length of sentence = 16, Length of vector = 100
# Sentence 241: Length of sentence = 9, Length of vector = 100
# Sentence 242: Length of sentence = 18, Length of vector = 100
# Sentence 243: Length of sentence = 5, Length of vector = 100
# Sentence 244: Length of sentence = 18, Length of vector = 100
# Sentence 245: Length of sentence = 9, Length of vector = 100
# Sentence 246: Length of sentence = 7, Length of vector = 100
# Sentence 247: Length of sentence = 6, Length of vector = 100
# Sentence 248: Length of sentence = 24, Length of vector = 100
# Sentence 249: Length of sentence = 11, Length of vector = 100
# Sentence 250: Length of sentence = 12, Length of vector = 100
# Sentence 251: Length of sentence = 9, Length of vector = 100
# Sentence 252: Length of sentence = 5, Length of vector = 100
# Sentence 253: Length of sentence = 6, Length of vector = 100
# Sentence 254: Length of sentence = 9, Length of vector = 100
# Sentence 255: Length of sentence = 8, Length of vector = 100
# Sentence 256: Length of sentence = 24, Length of vector = 100
# Sentence 257: Length of sentence = 9, Length of vector = 100
# Sentence 258: Length of sentence = 6, Length of vector = 100
# Sentence 259: Length of sentence = 26, Length of vector = 100
# Sentence 260: Length of sentence = 7, Length of vector = 100
# Sentence 261: Length of sentence = 7, Length of vector = 100
# Sentence 262: Length of sentence = 70, Length of vector = 100
# Sentence 263: Length of sentence = 5, Length of vector = 100
# Sentence 264: Length of sentence = 15, Length of vector = 100
# Sentence 265: Length of sentence = 13, Length of vector = 100
# Sentence 266: Length of sentence = 10, Length of vector = 100
# Sentence 267: Length of sentence = 21, Length of vector = 100
# Sentence 268: Length of sentence = 4, Length of vector = 100
# Sentence 269: Length of sentence = 26, Length of vector = 100
# Sentence 270: Length of sentence = 11, Length of vector = 100
# Sentence 271: Length of sentence = 8, Length of vector = 100
# Sentence 272: Length of sentence = 7, Length of vector = 100
# Sentence 273: Length of sentence = 25, Length of vector = 100
# Sentence 274: Length of sentence = 15, Length of vector = 100
# Sentence 275: Length of sentence = 20, Length of vector = 100
# Sentence 276: Length of sentence = 6, Length of vector = 100
# Sentence 277: Length of sentence = 6, Length of vector = 100
# Sentence 278: Length of sentence = 10, Length of vector = 100
# Sentence 279: Length of sentence = 21, Length of vector = 100
# Sentence 280: Length of sentence = 30, Length of vector = 100
# Sentence 281: Length of sentence = 20, Length of vector = 100
# Sentence 282: Length of sentence = 18, Length of vector = 100
# Sentence 283: Length of sentence = 11, Length of vector = 100
# Sentence 284: Length of sentence = 19, Length of vector = 100
# Sentence 285: Length of sentence = 9, Length of vector = 100
# Sentence 286: Length of sentence = 6, Length of vector = 100
# Sentence 287: Length of sentence = 6, Length of vector = 100
# Sentence 288: Length of sentence = 14, Length of vector = 100
# Sentence 289: Length of sentence = 5, Length of vector = 100
# Sentence 290: Length of sentence = 23, Length of vector = 100
# Sentence 291: Length of sentence = 5, Length of vector = 100
# Sentence 292: Length of sentence = 14, Length of vector = 100
# Sentence 293: Length of sentence = 37, Length of vector = 100
# Sentence 294: Length of sentence = 4, Length of vector = 100
# Sentence 295: Length of sentence = 23, Length of vector = 100
# Sentence 296: Length of sentence = 28, Length of vector = 100
# Sentence 297: Length of sentence = 9, Length of vector = 100
# Sentence 298: Length of sentence = 3, Length of vector = 100
# Sentence 299: Length of sentence = 22, Length of vector = 100
# Sentence 300: Length of sentence = 13, Length of vector = 100
# Sentence 301: Length of sentence = 13, Length of vector = 100
# Sentence 302: Length of sentence = 31, Length of vector = 100
# Sentence 303: Length of sentence = 35, Length of vector = 100
# Sentence 304: Length of sentence = 17, Length of vector = 100
# Sentence 305: Length of sentence = 9, Length of vector = 100
# Sentence 306: Length of sentence = 6, Length of vector = 100
# Sentence 307: Length of sentence = 13, Length of vector = 100
# Sentence 308: Length of sentence = 8, Length of vector = 100
# Sentence 309: Length of sentence = 37, Length of vector = 100
# Sentence 310: Length of sentence = 7, Length of vector = 100
# Sentence 311: Length of sentence = 12, Length of vector = 100
# Sentence 312: Length of sentence = 23, Length of vector = 100
# Sentence 313: Length of sentence = 23, Length of vector = 100
# Sentence 314: Length of sentence = 16, Length of vector = 100
# Sentence 315: Length of sentence = 8, Length of vector = 100
# Sentence 316: Length of sentence = 8, Length of vector = 100
# Sentence 317: Length of sentence = 17, Length of vector = 100
# Sentence 318: Length of sentence = 9, Length of vector = 100
# Sentence 319: Length of sentence = 3, Length of vector = 100
# Sentence 320: Length of sentence = 16, Length of vector = 100
# Sentence 321: Length of sentence = 12, Length of vector = 100
# Sentence 322: Length of sentence = 7, Length of vector = 100
# Sentence 323: Length of sentence = 11, Length of vector = 100
# Sentence 324: Length of sentence = 22, Length of vector = 100
# Sentence 325: Length of sentence = 10, Length of vector = 100
# Sentence 326: Length of sentence = 42, Length of vector = 100
# Sentence 327: Length of sentence = 6, Length of vector = 100
# Sentence 328: Length of sentence = 9, Length of vector = 100
# Sentence 329: Length of sentence = 22, Length of vector = 100
# Sentence 330: Length of sentence = 22, Length of vector = 100
# Sentence 331: Length of sentence = 22, Length of vector = 100
# Sentence 332: Length of sentence = 7, Length of vector = 100
# Sentence 333: Length of sentence = 8, Length of vector = 100
# Sentence 334: Length of sentence = 7, Length of vector = 100
# Sentence 335: Length of sentence = 21, Length of vector = 100
# Sentence 336: Length of sentence = 12, Length of vector = 100
# Sentence 337: Length of sentence = 15, Length of vector = 100
# Sentence 338: Length of sentence = 8, Length of vector = 100
# Sentence 339: Length of sentence = 17, Length of vector = 100
# Sentence 340: Length of sentence = 26, Length of vector = 100
# Sentence 341: Length of sentence = 5, Length of vector = 100
# Sentence 342: Length of sentence = 13, Length of vector = 100
# Sentence 343: Length of sentence = 4, Length of vector = 100
# Sentence 344: Length of sentence = 20, Length of vector = 100
# Sentence 345: Length of sentence = 10, Length of vector = 100
# Sentence 346: Length of sentence = 4, Length of vector = 100
# Sentence 347: Length of sentence = 4, Length of vector = 100
# Sentence 348: Length of sentence = 15, Length of vector = 100
# Sentence 349: Length of sentence = 17, Length of vector = 100
# Sentence 350: Length of sentence = 14, Length of vector = 100
# Sentence 351: Length of sentence = 6, Length of vector = 100
# Sentence 352: Length of sentence = 4, Length of vector = 100
# Sentence 353: Length of sentence = 10, Length of vector = 100
# Sentence 354: Length of sentence = 17, Length of vector = 100
# Sentence 355: Length of sentence = 14, Length of vector = 100
# Sentence 356: Length of sentence = 10, Length of vector = 100
# Sentence 357: Length of sentence = 5, Length of vector = 100
# Sentence 358: Length of sentence = 10, Length of vector = 100
# Sentence 359: Length of sentence = 6, Length of vector = 100
# Sentence 360: Length of sentence = 28, Length of vector = 100
# Sentence 361: Length of sentence = 10, Length of vector = 100
# Sentence 362: Length of sentence = 11, Length of vector = 100
# Sentence 363: Length of sentence = 15, Length of vector = 100
# Sentence 364: Length of sentence = 5, Length of vector = 100
# Sentence 365: Length of sentence = 17, Length of vector = 100
# Sentence 366: Length of sentence = 9, Length of vector = 100
# Sentence 367: Length of sentence = 19, Length of vector = 100
# Sentence 368: Length of sentence = 34, Length of vector = 100
# Sentence 369: Length of sentence = 8, Length of vector = 100
# Sentence 370: Length of sentence = 7, Length of vector = 100
# Sentence 371: Length of sentence = 19, Length of vector = 100
# Sentence 372: Length of sentence = 14, Length of vector = 100
# Sentence 373: Length of sentence = 13, Length of vector = 100
# Sentence 374: Length of sentence = 8, Length of vector = 100
# Sentence 375: Length of sentence = 8, Length of vector = 100
# Sentence 376: Length of sentence = 13, Length of vector = 100
# Sentence 377: Length of sentence = 29, Length of vector = 100
# Sentence 378: Length of sentence = 16, Length of vector = 100
# Sentence 379: Length of sentence = 8, Length of vector = 100
# Sentence 380: Length of sentence = 5, Length of vector = 100
# Sentence 381: Length of sentence = 22, Length of vector = 100
# Sentence 382: Length of sentence = 5, Length of vector = 100
# Sentence 383: Length of sentence = 58, Length of vector = 100
# Sentence 384: Length of sentence = 9, Length of vector = 100
# Sentence 385: Length of sentence = 28, Length of vector = 100
# Sentence 386: Length of sentence = 13, Length of vector = 100
# Sentence 387: Length of sentence = 3, Length of vector = 100
# Sentence 388: Length of sentence = 27, Length of vector = 100
# Sentence 389: Length of sentence = 16, Length of vector = 100
# Sentence 390: Length of sentence = 4, Length of vector = 100
# Sentence 391: Length of sentence = 12, Length of vector = 100
# Sentence 392: Length of sentence = 28, Length of vector = 100
# Sentence 393: Length of sentence = 4, Length of vector = 100
# Sentence 394: Length of sentence = 16, Length of vector = 100
# Sentence 395: Length of sentence = 31, Length of vector = 100
# Sentence 396: Length of sentence = 24, Length of vector = 100
# Sentence 397: Length of sentence = 6, Length of vector = 100
# Sentence 398: Length of sentence = 31, Length of vector = 100
# Sentence 399: Length of sentence = 18, Length of vector = 100
# Sentence 400: Length of sentence = 8, Length of vector = 100
# Sentence 401: Length of sentence = 21, Length of vector = 100
# Sentence 402: Length of sentence = 9, Length of vector = 100
# Sentence 403: Length of sentence = 28, Length of vector = 100
# Sentence 404: Length of sentence = 5, Length of vector = 100
# Sentence 405: Length of sentence = 16, Length of vector = 100
# Sentence 406: Length of sentence = 8, Length of vector = 100
# Sentence 407: Length of sentence = 15, Length of vector = 100
# Sentence 408: Length of sentence = 6, Length of vector = 100
# Sentence 409: Length of sentence = 9, Length of vector = 100
# Sentence 410: Length of sentence = 5, Length of vector = 100
# Sentence 411: Length of sentence = 12, Length of vector = 100
# Sentence 412: Length of sentence = 10, Length of vector = 100
# Sentence 413: Length of sentence = 22, Length of vector = 100
# Sentence 414: Length of sentence = 19, Length of vector = 100
# Sentence 415: Length of sentence = 13, Length of vector = 100
# Sentence 416: Length of sentence = 13, Length of vector = 100
# Sentence 417: Length of sentence = 6, Length of vector = 100
# Sentence 418: Length of sentence = 20, Length of vector = 100
# Sentence 419: Length of sentence = 16, Length of vector = 100
# Sentence 420: Length of sentence = 14, Length of vector = 100
# Sentence 421: Length of sentence = 30, Length of vector = 100
# Sentence 422: Length of sentence = 6, Length of vector = 100
# Sentence 423: Length of sentence = 23, Length of vector = 100
# Sentence 424: Length of sentence = 14, Length of vector = 100
# Sentence 425: Length of sentence = 8, Length of vector = 100
# Sentence 426: Length of sentence = 15, Length of vector = 100
# Sentence 427: Length of sentence = 10, Length of vector = 100
# Sentence 428: Length of sentence = 26, Length of vector = 100
# Sentence 429: Length of sentence = 8, Length of vector = 100
# Sentence 430: Length of sentence = 7, Length of vector = 100
# Sentence 431: Length of sentence = 4, Length of vector = 100
# Sentence 432: Length of sentence = 7, Length of vector = 100
# Sentence 433: Length of sentence = 38, Length of vector = 100
# Sentence 434: Length of sentence = 12, Length of vector = 100
# Sentence 435: Length of sentence = 8, Length of vector = 100
# Sentence 436: Length of sentence = 7, Length of vector = 100
# Sentence 437: Length of sentence = 7, Length of vector = 100
# Sentence 438: Length of sentence = 4, Length of vector = 100
# Sentence 439: Length of sentence = 11, Length of vector = 100
# Sentence 440: Length of sentence = 6, Length of vector = 100
# Sentence 441: Length of sentence = 9, Length of vector = 100
# Sentence 442: Length of sentence = 5, Length of vector = 100
# Sentence 443: Length of sentence = 4, Length of vector = 100
# Sentence 444: Length of sentence = 8, Length of vector = 100
# Sentence 445: Length of sentence = 21, Length of vector = 100
# Sentence 446: Length of sentence = 35, Length of vector = 100
# Sentence 447: Length of sentence = 27, Length of vector = 100
# Sentence 448: Length of sentence = 14, Length of vector = 100
# Sentence 449: Length of sentence = 7, Length of vector = 100
# Sentence 450: Length of sentence = 11, Length of vector = 100
# Sentence 451: Length of sentence = 19, Length of vector = 100
# Sentence 452: Length of sentence = 12, Length of vector = 100
# Sentence 453: Length of sentence = 20, Length of vector = 100
# Sentence 454: Length of sentence = 11, Length of vector = 100
# Sentence 455: Length of sentence = 12, Length of vector = 100
# Sentence 456: Length of sentence = 45, Length of vector = 100
# Sentence 457: Length of sentence = 8, Length of vector = 100
# Sentence 458: Length of sentence = 15, Length of vector = 100
# Sentence 459: Length of sentence = 4, Length of vector = 100
# Sentence 460: Length of sentence = 22, Length of vector = 100
# Sentence 461: Length of sentence = 6, Length of vector = 100
# Sentence 462: Length of sentence = 79, Length of vector = 100
# Sentence 463: Length of sentence = 12, Length of vector = 100
# Sentence 464: Length of sentence = 28, Length of vector = 100
# Sentence 465: Length of sentence = 5, Length of vector = 100
# Sentence 466: Length of sentence = 13, Length of vector = 100
# Sentence 467: Length of sentence = 26, Length of vector = 100
# Sentence 468: Length of sentence = 11, Length of vector = 100
# Sentence 469: Length of sentence = 29, Length of vector = 100
# Sentence 470: Length of sentence = 12, Length of vector = 100
# Sentence 471: Length of sentence = 26, Length of vector = 100
# Sentence 472: Length of sentence = 28, Length of vector = 100
# Sentence 473: Length of sentence = 7, Length of vector = 100
# Sentence 474: Length of sentence = 27, Length of vector = 100
# Sentence 475: Length of sentence = 11, Length of vector = 100
# Sentence 476: Length of sentence = 25, Length of vector = 100
# Sentence 477: Length of sentence = 6, Length of vector = 100
# Sentence 478: Length of sentence = 24, Length of vector = 100
# Sentence 479: Length of sentence = 9, Length of vector = 100
# Sentence 480: Length of sentence = 4, Length of vector = 100
# Sentence 481: Length of sentence = 24, Length of vector = 100
# Sentence 482: Length of sentence = 9, Length of vector = 100
# Sentence 483: Length of sentence = 13, Length of vector = 100
# Sentence 484: Length of sentence = 36, Length of vector = 100
# Sentence 485: Length of sentence = 18, Length of vector = 100
# Sentence 486: Length of sentence = 10, Length of vector = 100
# Sentence 487: Length of sentence = 11, Length of vector = 100
# Sentence 488: Length of sentence = 25, Length of vector = 100
# Sentence 489: Length of sentence = 25, Length of vector = 100
# Sentence 490: Length of sentence = 30, Length of vector = 100
# Sentence 491: Length of sentence = 16, Length of vector = 100
# Sentence 492: Length of sentence = 27, Length of vector = 100
# Sentence 493: Length of sentence = 8, Length of vector = 100
# Sentence 494: Length of sentence = 27, Length of vector = 100
# Sentence 495: Length of sentence = 11, Length of vector = 100
# Sentence 496: Length of sentence = 7, Length of vector = 100
# Sentence 497: Length of sentence = 18, Length of vector = 100
# Sentence 498: Length of sentence = 25, Length of vector = 100
# Sentence 499: Length of sentence = 6, Length of vector = 100
# Sentence 500: Length of sentence = 5, Length of vector = 100
# Sentence 501: Length of sentence = 21, Length of vector = 100
# Sentence 502: Length of sentence = 18, Length of vector = 100
# Sentence 503: Length of sentence = 8, Length of vector = 100
# Sentence 504: Length of sentence = 49, Length of vector = 100
# Sentence 505: Length of sentence = 13, Length of vector = 100
# Sentence 506: Length of sentence = 6, Length of vector = 100
# Sentence 507: Length of sentence = 8, Length of vector = 100
# Sentence 508: Length of sentence = 12, Length of vector = 100
# Sentence 509: Length of sentence = 8, Length of vector = 100
# Sentence 510: Length of sentence = 16, Length of vector = 100
# Sentence 511: Length of sentence = 27, Length of vector = 100
# Sentence 512: Length of sentence = 1, Length of vector = 100
# Sentence 513: Length of sentence = 24, Length of vector = 100
# Sentence 514: Length of sentence = 1, Length of vector = 100
# Sentence 515: Length of sentence = 56, Length of vector = 100
# Sentence 516: Length of sentence = 4, Length of vector = 100
# Sentence 517: Length of sentence = 4, Length of vector = 100
# Sentence 518: Length of sentence = 20, Length of vector = 100
# Sentence 519: Length of sentence = 4, Length of vector = 100
# Sentence 520: Length of sentence = 9, Length of vector = 100
# Sentence 521: Length of sentence = 6, Length of vector = 100
# Sentence 522: Length of sentence = 14, Length of vector = 100
# Sentence 523: Length of sentence = 41, Length of vector = 100
# Sentence 524: Length of sentence = 46, Length of vector = 100
# Sentence 525: Length of sentence = 8, Length of vector = 100
# Sentence 526: Length of sentence = 15, Length of vector = 100
# Sentence 527: Length of sentence = 22, Length of vector = 100
# Sentence 528: Length of sentence = 7, Length of vector = 100
# Sentence 529: Length of sentence = 12, Length of vector = 100
# Sentence 530: Length of sentence = 12, Length of vector = 100
# Sentence 531: Length of sentence = 23, Length of vector = 100
# Sentence 532: Length of sentence = 9, Length of vector = 100
# Sentence 533: Length of sentence = 21, Length of vector = 100
# Sentence 534: Length of sentence = 6, Length of vector = 100
# Sentence 535: Length of sentence = 27, Length of vector = 100
# Sentence 536: Length of sentence = 30, Length of vector = 100
# Sentence 537: Length of sentence = 7, Length of vector = 100
# Sentence 538: Length of sentence = 21, Length of vector = 100
# Sentence 539: Length of sentence = 9, Length of vector = 100
# Sentence 540: Length of sentence = 6, Length of vector = 100
# Sentence 541: Length of sentence = 14, Length of vector = 100
# Sentence 542: Length of sentence = 33, Length of vector = 100
# Sentence 543: Length of sentence = 24, Length of vector = 100
# Sentence 544: Length of sentence = 6, Length of vector = 100
# Sentence 545: Length of sentence = 9, Length of vector = 100
# Sentence 546: Length of sentence = 9, Length of vector = 100
# Sentence 547: Length of sentence = 22, Length of vector = 100
# Sentence 548: Length of sentence = 26, Length of vector = 100
# Sentence 549: Length of sentence = 22, Length of vector = 100
# Sentence 550: Length of sentence = 6, Length of vector = 100
# Sentence 551: Length of sentence = 5, Length of vector = 100
# Sentence 552: Length of sentence = 21, Length of vector = 100
# Sentence 553: Length of sentence = 9, Length of vector = 100
# Sentence 554: Length of sentence = 30, Length of vector = 100
# Sentence 555: Length of sentence = 18, Length of vector = 100
# Sentence 556: Length of sentence = 15, Length of vector = 100
# Sentence 557: Length of sentence = 27, Length of vector = 100
# Sentence 558: Length of sentence = 6, Length of vector = 100
# Sentence 559: Length of sentence = 15, Length of vector = 100
# Sentence 560: Length of sentence = 6, Length of vector = 100
# Sentence 561: Length of sentence = 23, Length of vector = 100
# Sentence 562: Length of sentence = 22, Length of vector = 100
# Sentence 563: Length of sentence = 23, Length of vector = 100
# Sentence 564: Length of sentence = 5, Length of vector = 100
# Sentence 565: Length of sentence = 9, Length of vector = 100
# Sentence 566: Length of sentence = 18, Length of vector = 100
# Sentence 567: Length of sentence = 7, Length of vector = 100
# Sentence 568: Length of sentence = 19, Length of vector = 100
# Sentence 569: Length of sentence = 5, Length of vector = 100
# Sentence 570: Length of sentence = 6, Length of vector = 100
# Sentence 571: Length of sentence = 9, Length of vector = 100
# Sentence 572: Length of sentence = 18, Length of vector = 100
# Sentence 573: Length of sentence = 8, Length of vector = 100
# Sentence 574: Length of sentence = 31, Length of vector = 100
# Sentence 575: Length of sentence = 1, Length of vector = 100
# Sentence 576: Length of sentence = 15, Length of vector = 100
# Sentence 577: Length of sentence = 17, Length of vector = 100
# Sentence 578: Length of sentence = 30, Length of vector = 100
# Sentence 579: Length of sentence = 25, Length of vector = 100
# Sentence 580: Length of sentence = 11, Length of vector = 100
# Sentence 581: Length of sentence = 6, Length of vector = 100
# Sentence 582: Length of sentence = 11, Length of vector = 100
# Sentence 583: Length of sentence = 9, Length of vector = 100
# Sentence 584: Length of sentence = 17, Length of vector = 100
# Sentence 585: Length of sentence = 30, Length of vector = 100
# Sentence 586: Length of sentence = 4, Length of vector = 100
# Sentence 587: Length of sentence = 14, Length of vector = 100
# Sentence 588: Length of sentence = 19, Length of vector = 100
# Sentence 589: Length of sentence = 9, Length of vector = 100
# Sentence 590: Length of sentence = 3, Length of vector = 100
# Sentence 591: Length of sentence = 3, Length of vector = 100
# Sentence 592: Length of sentence = 6, Length of vector = 100
# Sentence 593: Length of sentence = 4, Length of vector = 100
# Sentence 594: Length of sentence = 23, Length of vector = 100
# Sentence 595: Length of sentence = 23, Length of vector = 100
# Sentence 596: Length of sentence = 11, Length of vector = 100
# Sentence 597: Length of sentence = 9, Length of vector = 100
# Sentence 598: Length of sentence = 4, Length of vector = 100
# Sentence 599: Length of sentence = 44, Length of vector = 100
# Sentence 600: Length of sentence = 20, Length of vector = 100
# Sentence 601: Length of sentence = 7, Length of vector = 100
# Sentence 602: Length of sentence = 24, Length of vector = 100
# Sentence 603: Length of sentence = 7, Length of vector = 100
# Sentence 604: Length of sentence = 8, Length of vector = 100
# Sentence 605: Length of sentence = 7, Length of vector = 100
# Sentence 606: Length of sentence = 15, Length of vector = 100
# Sentence 607: Length of sentence = 14, Length of vector = 100
# Sentence 608: Length of sentence = 25, Length of vector = 100
# Sentence 609: Length of sentence = 8, Length of vector = 100
# Sentence 610: Length of sentence = 12, Length of vector = 100
# Sentence 611: Length of sentence = 7, Length of vector = 100
# Sentence 612: Length of sentence = 27, Length of vector = 100
# Sentence 613: Length of sentence = 13, Length of vector = 100
# Sentence 614: Length of sentence = 8, Length of vector = 100
# Sentence 615: Length of sentence = 8, Length of vector = 100
# Sentence 616: Length of sentence = 6, Length of vector = 100
# Sentence 617: Length of sentence = 30, Length of vector = 100
# Sentence 618: Length of sentence = 9, Length of vector = 100
# Sentence 619: Length of sentence = 8, Length of vector = 100
# Sentence 620: Length of sentence = 4, Length of vector = 100
# Sentence 621: Length of sentence = 15, Length of vector = 100
# Sentence 622: Length of sentence = 13, Length of vector = 100
# Sentence 623: Length of sentence = 7, Length of vector = 100
# Sentence 624: Length of sentence = 7, Length of vector = 100
# Sentence 625: Length of sentence = 16, Length of vector = 100
# Sentence 626: Length of sentence = 8, Length of vector = 100
# Sentence 627: Length of sentence = 19, Length of vector = 100
# Sentence 628: Length of sentence = 15, Length of vector = 100
# Sentence 629: Length of sentence = 6, Length of vector = 100
# Sentence 630: Length of sentence = 16, Length of vector = 100
# Sentence 631: Length of sentence = 17, Length of vector = 100
# Sentence 632: Length of sentence = 12, Length of vector = 100
# Sentence 633: Length of sentence = 7, Length of vector = 100
# Sentence 634: Length of sentence = 11, Length of vector = 100
# Sentence 635: Length of sentence = 24, Length of vector = 100
# Sentence 636: Length of sentence = 30, Length of vector = 100
# Sentence 637: Length of sentence = 23, Length of vector = 100
# Sentence 638: Length of sentence = 21, Length of vector = 100
# Sentence 639: Length of sentence = 52, Length of vector = 100
# Sentence 640: Length of sentence = 15, Length of vector = 100
# Sentence 641: Length of sentence = 4, Length of vector = 100
# Sentence 642: Length of sentence = 42, Length of vector = 100
# Sentence 643: Length of sentence = 5, Length of vector = 100
# Sentence 644: Length of sentence = 8, Length of vector = 100
# Sentence 645: Length of sentence = 27, Length of vector = 100
# Sentence 646: Length of sentence = 24, Length of vector = 100
# Sentence 647: Length of sentence = 29, Length of vector = 100
# Sentence 648: Length of sentence = 13, Length of vector = 100
# Sentence 649: Length of sentence = 23, Length of vector = 100
# Sentence 650: Length of sentence = 22, Length of vector = 100
# Sentence 651: Length of sentence = 7, Length of vector = 100
# Sentence 652: Length of sentence = 5, Length of vector = 100
# Sentence 653: Length of sentence = 42, Length of vector = 100
# Sentence 654: Length of sentence = 6, Length of vector = 100
# Sentence 655: Length of sentence = 21, Length of vector = 100
# Sentence 656: Length of sentence = 3, Length of vector = 100
# Sentence 657: Length of sentence = 7, Length of vector = 100
# Sentence 658: Length of sentence = 18, Length of vector = 100
# Sentence 659: Length of sentence = 14, Length of vector = 100
# Sentence 660: Length of sentence = 20, Length of vector = 100
# Sentence 661: Length of sentence = 6, Length of vector = 100
# Sentence 662: Length of sentence = 5, Length of vector = 100
# Sentence 663: Length of sentence = 3, Length of vector = 100
# Sentence 664: Length of sentence = 30, Length of vector = 100
# Sentence 665: Length of sentence = 17, Length of vector = 100
# Sentence 666: Length of sentence = 27, Length of vector = 100
# Sentence 667: Length of sentence = 5, Length of vector = 100
# Sentence 668: Length of sentence = 10, Length of vector = 100
# Sentence 669: Length of sentence = 5, Length of vector = 100
# Sentence 670: Length of sentence = 8, Length of vector = 100
# Sentence 671: Length of sentence = 18, Length of vector = 100
# Sentence 672: Length of sentence = 24, Length of vector = 100
# Sentence 673: Length of sentence = 41, Length of vector = 100
# Sentence 674: Length of sentence = 5, Length of vector = 100
# Sentence 675: Length of sentence = 7, Length of vector = 100
# Sentence 676: Length of sentence = 20, Length of vector = 100
# Sentence 677: Length of sentence = 37, Length of vector = 100
# Sentence 678: Length of sentence = 13, Length of vector = 100
# Sentence 679: Length of sentence = 16, Length of vector = 100
# Sentence 680: Length of sentence = 9, Length of vector = 100
# Sentence 681: Length of sentence = 5, Length of vector = 100
# Sentence 682: Length of sentence = 25, Length of vector = 100
# Sentence 683: Length of sentence = 8, Length of vector = 100
# Sentence 684: Length of sentence = 17, Length of vector = 100
# Sentence 685: Length of sentence = 16, Length of vector = 100
# Sentence 686: Length of sentence = 28, Length of vector = 100
# Sentence 687: Length of sentence = 15, Length of vector = 100
# Sentence 688: Length of sentence = 4, Length of vector = 100
# Sentence 689: Length of sentence = 13, Length of vector = 100
# Sentence 690: Length of sentence = 10, Length of vector = 100
# Sentence 691: Length of sentence = 5, Length of vector = 100
# Sentence 692: Length of sentence = 23, Length of vector = 100
# Sentence 693: Length of sentence = 21, Length of vector = 100
# Sentence 694: Length of sentence = 5, Length of vector = 100
# Sentence 695: Length of sentence = 4, Length of vector = 100
# Sentence 696: Length of sentence = 10, Length of vector = 100
# Sentence 697: Length of sentence = 16, Length of vector = 100
# Sentence 698: Length of sentence = 24, Length of vector = 100
# Sentence 699: Length of sentence = 8, Length of vector = 100
# Sentence 700: Length of sentence = 6, Length of vector = 100
# Sentence 701: Length of sentence = 14, Length of vector = 100
# Sentence 702: Length of sentence = 12, Length of vector = 100
# Sentence 703: Length of sentence = 15, Length of vector = 100
# Sentence 704: Length of sentence = 9, Length of vector = 100
# Sentence 705: Length of sentence = 3, Length of vector = 100
# Sentence 706: Length of sentence = 8, Length of vector = 100
# Sentence 707: Length of sentence = 8, Length of vector = 100
# Sentence 708: Length of sentence = 13, Length of vector = 100
# Sentence 709: Length of sentence = 21, Length of vector = 100
# Sentence 710: Length of sentence = 13, Length of vector = 100
# Sentence 711: Length of sentence = 9, Length of vector = 100
# Sentence 712: Length of sentence = 12, Length of vector = 100
# Sentence 713: Length of sentence = 5, Length of vector = 100
# Sentence 714: Length of sentence = 25, Length of vector = 100
# Sentence 715: Length of sentence = 5, Length of vector = 100
# Sentence 716: Length of sentence = 3, Length of vector = 100
# Sentence 717: Length of sentence = 5, Length of vector = 100
# Sentence 718: Length of sentence = 17, Length of vector = 100
# Sentence 719: Length of sentence = 24, Length of vector = 100
# Sentence 720: Length of sentence = 22, Length of vector = 100
# Sentence 721: Length of sentence = 7, Length of vector = 100
# Sentence 722: Length of sentence = 30, Length of vector = 100
# Sentence 723: Length of sentence = 31, Length of vector = 100
# Sentence 724: Length of sentence = 9, Length of vector = 100
# Sentence 725: Length of sentence = 17, Length of vector = 100
# Sentence 726: Length of sentence = 9, Length of vector = 100
# Sentence 727: Length of sentence = 5, Length of vector = 100
# Sentence 728: Length of sentence = 12, Length of vector = 100
# Sentence 729: Length of sentence = 24, Length of vector = 100
# Sentence 730: Length of sentence = 9, Length of vector = 100
# Sentence 731: Length of sentence = 6, Length of vector = 100
# Sentence 732: Length of sentence = 6, Length of vector = 100
# Sentence 733: Length of sentence = 9, Length of vector = 100
# Sentence 734: Length of sentence = 7, Length of vector = 100
# Sentence 735: Length of sentence = 17, Length of vector = 100
# Sentence 736: Length of sentence = 11, Length of vector = 100
# Sentence 737: Length of sentence = 15, Length of vector = 100
# Sentence 738: Length of sentence = 17, Length of vector = 100
# Sentence 739: Length of sentence = 4, Length of vector = 100
# Sentence 740: Length of sentence = 6, Length of vector = 100
# Sentence 741: Length of sentence = 22, Length of vector = 100
# Sentence 742: Length of sentence = 6, Length of vector = 100
# Sentence 743: Length of sentence = 10, Length of vector = 100
# Sentence 744: Length of sentence = 7, Length of vector = 100
# Sentence 745: Length of sentence = 22, Length of vector = 100
# Sentence 746: Length of sentence = 8, Length of vector = 100
# Sentence 747: Length of sentence = 44, Length of vector = 100
# Sentence 748: Length of sentence = 21, Length of vector = 100
# Sentence 749: Length of sentence = 7, Length of vector = 100
# Sentence 750: Length of sentence = 18, Length of vector = 100
# Sentence 751: Length of sentence = 30, Length of vector = 100
# Sentence 752: Length of sentence = 9, Length of vector = 100
# Sentence 753: Length of sentence = 8, Length of vector = 100
# Sentence 754: Length of sentence = 15, Length of vector = 100
# Sentence 755: Length of sentence = 14, Length of vector = 100
# Sentence 756: Length of sentence = 10, Length of vector = 100
# Sentence 757: Length of sentence = 8, Length of vector = 100
# Sentence 758: Length of sentence = 21, Length of vector = 100
# Sentence 759: Length of sentence = 24, Length of vector = 100
# Sentence 760: Length of sentence = 14, Length of vector = 100
# Sentence 761: Length of sentence = 22, Length of vector = 100
# Sentence 762: Length of sentence = 8, Length of vector = 100
# Sentence 763: Length of sentence = 49, Length of vector = 100
# Sentence 764: Length of sentence = 3, Length of vector = 100
# Sentence 765: Length of sentence = 29, Length of vector = 100
# Sentence 766: Length of sentence = 7, Length of vector = 100
# Sentence 767: Length of sentence = 12, Length of vector = 100
# Sentence 768: Length of sentence = 19, Length of vector = 100
# Sentence 769: Length of sentence = 16, Length of vector = 100
# Sentence 770: Length of sentence = 21, Length of vector = 100
# Sentence 771: Length of sentence = 19, Length of vector = 100
# Sentence 772: Length of sentence = 27, Length of vector = 100
# Sentence 773: Length of sentence = 12, Length of vector = 100
# Sentence 774: Length of sentence = 7, Length of vector = 100
# Sentence 775: Length of sentence = 21, Length of vector = 100
# Sentence 776: Length of sentence = 25, Length of vector = 100
# Sentence 777: Length of sentence = 7, Length of vector = 100
# Sentence 778: Length of sentence = 20, Length of vector = 100
# Sentence 779: Length of sentence = 5, Length of vector = 100
# Sentence 780: Length of sentence = 15, Length of vector = 100
# ...
# Sentence 857: Length of sentence = 8, Length of vector = 100
# Sentence 858: Length of sentence = 11, Length of vector = 100
# Sentence 859: Length of sentence = 8, Length of vector = 100
# Sentence 860: Length of sentence = 1, Length of vector = 100
# Sentence 861: Length of sentence = 19, Length of vector = 100
# Sentence 862: Length of sentence = 13, Length of vector = 100
# Sentence 863: Length of sentence = 8, Length of vector = 100
# Sentence 864: Length of sentence = 14, Length of vector = 100
# Sentence 865: Length of sentence = 6, Length of vector = 100
# Sentence 866: Length of sentence = 4, Length of vector = 100
# Sentence 867: Length of sentence = 6, Length of vector = 100
# Sentence 868: Length of sentence = 23, Length of vector = 100
# Sentence 869: Length of sentence = 18, Length of vector = 100
# Sentence 870: Length of sentence = 5, Length of vector = 100
# Sentence 871: Length of sentence = 13, Length of vector = 100
# Sentence 872: Length of sentence = 7, Length of vector = 100
# Sentence 873: Length of sentence = 33, Length of vector = 100
# Sentence 874: Length of sentence = 10, Length of vector = 100
# Sentence 875: Length of sentence = 21, Length of vector = 100
# Sentence 876: Length of sentence = 5, Length of vector = 100
# Sentence 877: Length of sentence = 21, Length of vector = 100
# Sentence 878: Length of sentence = 21, Length of vector = 100
# Sentence 879: Length of sentence = 12, Length of vector = 100
# Sentence 880: Length of sentence = 5, Length of vector = 100
# Sentence 881: Length of sentence = 10, Length of vector = 100
# Sentence 882: Length of sentence = 17, Length of vector = 100
# Sentence 883: Length of sentence = 14, Length of vector = 100
# Sentence 884: Length of sentence = 9, Length of vector = 100
# Sentence 885: Length of sentence = 2, Length of vector = 100
# Sentence 886: Length of sentence = 7, Length of vector = 100
# Sentence 887: Length of sentence = 3, Length of vector = 100
# Sentence 888: Length of sentence = 4, Length of vector = 100
# Sentence 889: Length of sentence = 11, Length of vector = 100
# Sentence 890: Length of sentence = 5, Length of vector = 100
# Sentence 891: Length of sentence = 11, Length of vector = 100
# Sentence 892: Length of sentence = 4, Length of vector = 100
# Sentence 893: Length of sentence = 11, Length of vector = 100
# Sentence 894: Length of sentence = 28, Length of vector = 100
# Sentence 895: Length of sentence = 20, Length of vector = 100
# Sentence 896: Length of sentence = 6, Length of vector = 100
# Sentence 897: Length of sentence = 18, Length of vector = 100
# Sentence 898: Length of sentence = 29, Length of vector = 100
# Sentence 899: Length of sentence = 3, Length of vector = 100
# Sentence 900: Length of sentence = 15, Length of vector = 100
# Sentence 901: Length of sentence = 23, Length of vector = 100
# Sentence 902: Length of sentence = 11, Length of vector = 100
# Sentence 903: Length of sentence = 4, Length of vector = 100
# Sentence 904: Length of sentence = 4, Length of vector = 100
# Sentence 905: Length of sentence = 9, Length of vector = 100
# Sentence 906: Length of sentence = 17, Length of vector = 100
# Sentence 907: Length of sentence = 6, Length of vector = 100
# Sentence 908: Length of sentence = 9, Length of vector = 100
# Sentence 909: Length of sentence = 6, Length of vector = 100
# Sentence 910: Length of sentence = 51, Length of vector = 100
# Sentence 911: Length of sentence = 20, Length of vector = 100
# Sentence 912: Length of sentence = 38, Length of vector = 100
# Sentence 913: Length of sentence = 23, Length of vector = 100
# Sentence 914: Length of sentence = 24, Length of vector = 100
# Sentence 915: Length of sentence = 24, Length of vector = 100
# Sentence 916: Length of sentence = 31, Length of vector = 100
# Sentence 917: Length of sentence = 22, Length of vector = 100
# Sentence 918: Length of sentence = 5, Length of vector = 100
# Sentence 919: Length of sentence = 33, Length of vector = 100
# Sentence 920: Length of sentence = 17, Length of vector = 100
# Sentence 921: Length of sentence = 23, Length of vector = 100
# Sentence 922: Length of sentence = 4, Length of vector = 100
# Sentence 923: Length of sentence = 30, Length of vector = 100
# Sentence 924: Length of sentence = 17, Length of vector = 100
# Sentence 925: Length of sentence = 4, Length of vector = 100
# Sentence 926: Length of sentence = 25, Length of vector = 100
# Sentence 927: Length of sentence = 6, Length of vector = 100
# Sentence 928: Length of sentence = 28, Length of vector = 100
# Sentence 929: Length of sentence = 12, Length of vector = 100
# Sentence 930: Length of sentence = 11, Length of vector = 100
# Sentence 931: Length of sentence = 2, Length of vector = 100
# Sentence 932: Length of sentence = 28, Length of vector = 100
# Sentence 933: Length of sentence = 7, Length of vector = 100
# Sentence 934: Length of sentence = 10, Length of vector = 100
# Sentence 935: Length of sentence = 10, Length of vector = 100
# Sentence 936: Length of sentence = 25, Length of vector = 100
# Sentence 937: Length of sentence = 5, Length of vector = 100
# Sentence 938: Length of sentence = 15, Length of vector = 100
# Sentence 939: Length of sentence = 23, Length of vector = 100
# Sentence 940: Length of sentence = 5, Length of vector = 100
# Sentence 941: Length of sentence = 8, Length of vector = 100
# Sentence 942: Length of sentence = 8, Length of vector = 100
# Sentence 943: Length of sentence = 6, Length of vector = 100
# Sentence 944: Length of sentence = 30, Length of vector = 100
# Sentence 945: Length of sentence = 11, Length of vector = 100
# Sentence 946: Length of sentence = 13, Length of vector = 100
# Sentence 947: Length of sentence = 5, Length of vector = 100
# Sentence 948: Length of sentence = 25, Length of vector = 100
# Sentence 949: Length of sentence = 25, Length of vector = 100
# Sentence 950: Length of sentence = 13, Length of vector = 100
# Sentence 951: Length of sentence = 21, Length of vector = 100
# Sentence 952: Length of sentence = 7, Length of vector = 100
# Sentence 953: Length of sentence = 6, Length of vector = 100
# Sentence 954: Length of sentence = 25, Length of vector = 100
# Sentence 955: Length of sentence = 6, Length of vector = 100
# Sentence 956: Length of sentence = 22, Length of vector = 100
# Sentence 957: Length of sentence = 5, Length of vector = 100
# Sentence 958: Length of sentence = 20, Length of vector = 100
# Sentence 959: Length of sentence = 6, Length of vector = 100
# Sentence 960: Length of sentence = 11, Length of vector = 100
# Sentence 961: Length of sentence = 24, Length of vector = 100
# Sentence 962: Length of sentence = 6, Length of vector = 100
# Sentence 963: Length of sentence = 9, Length of vector = 100
# Sentence 964: Length of sentence = 16, Length of vector = 100
# Sentence 965: Length of sentence = 24, Length of vector = 100
# Sentence 966: Length of sentence = 15, Length of vector = 100
# Sentence 967: Length of sentence = 6, Length of vector = 100
# Sentence 968: Length of sentence = 7, Length of vector = 100
# Sentence 969: Length of sentence = 21, Length of vector = 100
# Sentence 970: Length of sentence = 7, Length of vector = 100
# Sentence 971: Length of sentence = 25, Length of vector = 100
# Sentence 972: Length of sentence = 17, Length of vector = 100
# Sentence 973: Length of sentence = 14, Length of vector = 100
# Sentence 974: Length of sentence = 15, Length of vector = 100
# Sentence 975: Length of sentence = 9, Length of vector = 100
# Sentence 976: Length of sentence = 17, Length of vector = 100
# Sentence 977: Length of sentence = 9, Length of vector = 100
# Sentence 978: Length of sentence = 8, Length of vector = 100
# Sentence 979: Length of sentence = 1, Length of vector = 100
# Sentence 980: Length of sentence = 21, Length of vector = 100
# Sentence 981: Length of sentence = 6, Length of vector = 100
# Sentence 982: Length of sentence = 7, Length of vector = 100
# Sentence 983: Length of sentence = 15, Length of vector = 100
# Sentence 984: Length of sentence = 8, Length of vector = 100
# Sentence 985: Length of sentence = 32, Length of vector = 100
# Sentence 986: Length of sentence = 26, Length of vector = 100
# Sentence 987: Length of sentence = 10, Length of vector = 100
# Sentence 988: Length of sentence = 9, Length of vector = 100
# Sentence 989: Length of sentence = 21, Length of vector = 100
# Sentence 990: Length of sentence = 25, Length of vector = 100
# Sentence 991: Length of sentence = 23, Length of vector = 100
# Sentence 992: Length of sentence = 7, Length of vector = 100
# Sentence 993: Length of sentence = 8, Length of vector = 100
# Sentence 994: Length of sentence = 9, Length of vector = 100
# Sentence 995: Length of sentence = 14, Length of vector = 100
# Sentence 996: Length of sentence = 21, Length of vector = 100
# Sentence 997: Length of sentence = 26, Length of vector = 100
# Sentence 998: Length of sentence = 7, Length of vector = 100
# Sentence 999: Length of sentence = 5, Length of vector = 100
# Sentence 1000: Length of sentence = 4, Length of vector = 100
# Sentence 1001: Length of sentence = 6, Length of vector = 100
# Sentence 1002: Length of sentence = 7, Length of vector = 100
# Sentence 1003: Length of sentence = 8, Length of vector = 100
# Sentence 1004: Length of sentence = 5, Length of vector = 100
# Sentence 1005: Length of sentence = 13, Length of vector = 100
# Sentence 1006: Length of sentence = 6, Length of vector = 100
# Sentence 1007: Length of sentence = 7, Length of vector = 100
# Sentence 1008: Length of sentence = 9, Length of vector = 100
# Sentence 1009: Length of sentence = 11, Length of vector = 100
# Sentence 1010: Length of sentence = 26, Length of vector = 100
# Sentence 1011: Length of sentence = 11, Length of vector = 100
# Sentence 1012: Length of sentence = 28, Length of vector = 100
# Sentence 1013: Length of sentence = 8, Length of vector = 100
# Sentence 1014: Length of sentence = 10, Length of vector = 100
# Sentence 1015: Length of sentence = 6, Length of vector = 100
# Sentence 1016: Length of sentence = 22, Length of vector = 100
# Sentence 1017: Length of sentence = 4, Length of vector = 100
# Sentence 1018: Length of sentence = 42, Length of vector = 100
# Sentence 1019: Length of sentence = 3, Length of vector = 100
# Sentence 1020: Length of sentence = 20, Length of vector = 100
# Sentence 1021: Length of sentence = 8, Length of vector = 100
# Sentence 1022: Length of sentence = 8, Length of vector = 100
# Sentence 1023: Length of sentence = 26, Length of vector = 100
# Sentence 1024: Length of sentence = 24, Length of vector = 100
# Sentence 1025: Length of sentence = 7, Length of vector = 100
# Sentence 1026: Length of sentence = 2, Length of vector = 100
# Sentence 1027: Length of sentence = 20, Length of vector = 100
# Sentence 1028: Length of sentence = 5, Length of vector = 100
# Sentence 1029: Length of sentence = 16, Length of vector = 100
# Sentence 1030: Length of sentence = 29, Length of vector = 100
# Sentence 1031: Length of sentence = 19, Length of vector = 100
# Sentence 1032: Length of sentence = 5, Length of vector = 100
# Sentence 1033: Length of sentence = 29, Length of vector = 100
# Sentence 1034: Length of sentence = 6, Length of vector = 100
# Sentence 1035: Length of sentence = 3, Length of vector = 100
# Sentence 1036: Length of sentence = 20, Length of vector = 100
# Sentence 1037: Length of sentence = 2, Length of vector = 100
# Sentence 1038: Length of sentence = 21, Length of vector = 100
# Sentence 1039: Length of sentence = 5, Length of vector = 100
# Sentence 1040: Length of sentence = 25, Length of vector = 100
# Sentence 1041: Length of sentence = 10, Length of vector = 100
# Sentence 1042: Length of sentence = 3, Length of vector = 100
# Sentence 1043: Length of sentence = 23, Length of vector = 100
# Sentence 1044: Length of sentence = 9, Length of vector = 100
# Sentence 1045: Length of sentence = 15, Length of vector = 100
# Sentence 1046: Length of sentence = 18, Length of vector = 100
# Sentence 1047: Length of sentence = 30, Length of vector = 100
# Sentence 1048: Length of sentence = 28, Length of vector = 100
# Sentence 1049: Length of sentence = 11, Length of vector = 100
# Sentence 1050: Length of sentence = 16, Length of vector = 100
# Sentence 1051: Length of sentence = 5, Length of vector = 100
# Sentence 1052: Length of sentence = 46, Length of vector = 100
# Sentence 1053: Length of sentence = 27, Length of vector = 100
# Sentence 1054: Length of sentence = 1, Length of vector = 100
# Sentence 1055: Length of sentence = 77, Length of vector = 100
# Sentence 1056: Length of sentence = 31, Length of vector = 100
# Sentence 1057: Length of sentence = 14, Length of vector = 100
# Sentence 1058: Length of sentence = 110, Length of vector = 100
# Sentence 1059: Length of sentence = 5, Length of vector = 100
# Sentence 1060: Length of sentence = 17, Length of vector = 100
# Sentence 1061: Length of sentence = 19, Length of vector = 100
# Sentence 1062: Length of sentence = 9, Length of vector = 100
# Sentence 1063: Length of sentence = 14, Length of vector = 100
# Sentence 1064: Length of sentence = 9, Length of vector = 100
# Sentence 1065: Length of sentence = 6, Length of vector = 100
# Sentence 1066: Length of sentence = 29, Length of vector = 100
# Sentence 1067: Length of sentence = 5, Length of vector = 100
# Sentence 1068: Length of sentence = 19, Length of vector = 100
# Sentence 1069: Length of sentence = 5, Length of vector = 100
# Sentence 1070: Length of sentence = 22, Length of vector = 100
# Sentence 1071: Length of sentence = 6, Length of vector = 100
# Sentence 1072: Length of sentence = 16, Length of vector = 100
# Sentence 1073: Length of sentence = 9, Length of vector = 100
# Sentence 1074: Length of sentence = 25, Length of vector = 100
# Sentence 1075: Length of sentence = 10, Length of vector = 100
# Sentence 1076: Length of sentence = 21, Length of vector = 100
# Sentence 1077: Length of sentence = 5, Length of vector = 100
# Sentence 1078: Length of sentence = 5, Length of vector = 100
# Sentence 1079: Length of sentence = 8, Length of vector = 100
# Sentence 1080: Length of sentence = 10, Length of vector = 100
# Sentence 1081: Length of sentence = 8, Length of vector = 100
# Sentence 1082: Length of sentence = 11, Length of vector = 100
# Sentence 1083: Length of sentence = 21, Length of vector = 100
# Sentence 1084: Length of sentence = 21, Length of vector = 100
# Sentence 1085: Length of sentence = 2, Length of vector = 100
# Sentence 1086: Length of sentence = 21, Length of vector = 100
# Sentence 1087: Length of sentence = 24, Length of vector = 100
# Sentence 1088: Length of sentence = 22, Length of vector = 100
# Sentence 1089: Length of sentence = 24, Length of vector = 100
# Sentence 1090: Length of sentence = 6, Length of vector = 100
# Sentence 1091: Length of sentence = 12, Length of vector = 100
# Sentence 1092: Length of sentence = 23, Length of vector = 100
# Sentence 1093: Length of sentence = 5, Length of vector = 100
# Sentence 1094: Length of sentence = 6, Length of vector = 100
# Sentence 1095: Length of sentence = 9, Length of vector = 100
# Sentence 1096: Length of sentence = 11, Length of vector = 100
# Sentence 1097: Length of sentence = 13, Length of vector = 100
# Sentence 1098: Length of sentence = 8, Length of vector = 100
# Sentence 1099: Length of sentence = 30, Length of vector = 100
# Sentence 1100: Length of sentence = 6, Length of vector = 100
# Sentence 1101: Length of sentence = 7, Length of vector = 100
# Sentence 1102: Length of sentence = 6, Length of vector = 100
# Sentence 1103: Length of sentence = 29, Length of vector = 100
# Sentence 1104: Length of sentence = 5, Length of vector = 100
# Sentence 1105: Length of sentence = 8, Length of vector = 100
# Sentence 1106: Length of sentence = 6, Length of vector = 100
# Sentence 1107: Length of sentence = 7, Length of vector = 100
# Sentence 1108: Length of sentence = 5, Length of vector = 100
# Sentence 1109: Length of sentence = 6, Length of vector = 100
# Sentence 1110: Length of sentence = 15, Length of vector = 100
# Sentence 1111: Length of sentence = 8, Length of vector = 100
# Sentence 1112: Length of sentence = 4, Length of vector = 100
# Sentence 1113: Length of sentence = 5, Length of vector = 100
# Sentence 1114: Length of sentence = 1, Length of vector = 100
