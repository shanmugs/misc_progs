# %% [markdown]
# # Using a Public API with Python

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '8839d3f8-4bce-45ac-8059-c9c329c395c1',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)


# To run: jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10
# Gives the local:
# http://localhost:8889/?token=3683b264983dd64cbee16a39830773756134364fcd001a8f

# %%
type (data)
# Out:
# dict

# %%
#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

#This normalizes the data and makes it all pretty in a dataframe
pd.json_normalize(data['data'])
# Out:
#          id                           name  symbol  \
# 0         1                        Bitcoin     BTC
# 1      1027                       Ethereum     ETH
# 2       825                    Tether USDt    USDT
# 3      1839                            BNB     BNB
# 4      5426                         Solana     SOL
# ...     ...                            ...     ...
# 4995  19182                       Gametree  GTCOIN
# 4996  16285                       Triathon    GEON
# 4997  28291                            Apu     APU
# 4998  26160                          Toshe   TOSHE
# 4999  20615  Fatih Karagümrük SK Fan Token    FKSK
#
#                                slug  num_market_pairs  \
# 0                           bitcoin             10938
# 1                          ethereum              8610
# 2                            tether             79608
# 3                               bnb              2113
# 4                            solana               643
# ...

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])

df
# Out:
#          id                           name  symbol  \
# 0         1                        Bitcoin     BTC
# 1      1027                       Ethereum     ETH
# 2       825                    Tether USDt    USDT
# 3      1839                            BNB     BNB
# 4      5426                         Solana     SOL
# ...     ...                            ...     ...
# 4995  19182                       Gametree  GTCOIN
# 4996  16285                       Triathon    GEON
# 4997  28291                            Apu     APU
# 4998  26160                          Toshe   TOSHE
# 4999  20615  Fatih Karagümrük SK Fan Token    FKSK
#
#                                slug  num_market_pairs  \
# 0                           bitcoin             10938
# 1                          ethereum              8610
# 2                            tether             79608
# 3                               bnb              2113
# 4                            solana               643
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 36 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  5000 non-null   int64
#  1   name                                5000 non-null   object
#  2   symbol                              5000 non-null   object
#  3   slug                                5000 non-null   object
#  4   num_market_pairs                    5000 non-null   int64
#  5   date_added                          5000 non-null   object
#  6   tags                                5000 non-null   object
#  7   max_supply                          3549 non-null   float64
#  8   circulating_supply                  5000 non-null   float64
#  9   total_supply                        5000 non-null   object
#  10  infinite_supply                     5000 non-null   bool
# ...

# %%
# This reates "timestamp"

df['timestamp'] = pd.to_datetime('now')  #the time now
df
# Out:
#          id                           name  symbol  \
# 0         1                        Bitcoin     BTC
# 1      1027                       Ethereum     ETH
# 2       825                    Tether USDt    USDT
# 3      1839                            BNB     BNB
# 4      5426                         Solana     SOL
# ...     ...                            ...     ...
# 4995  19182                       Gametree  GTCOIN
# 4996  16285                       Triathon    GEON
# 4997  28291                            Apu     APU
# 4998  26160                          Toshe   TOSHE
# 4999  20615  Fatih Karagümrük SK Fan Token    FKSK
#
#                                slug  num_market_pairs  \
# 0                           bitcoin             10938
# 1                          ethereum              8610
# 2                            tether             79608
# 3                               bnb              2113
# 4                            solana               643
# ...

# %%
# Save table as csv
df.to_csv("data/CoinMarketCap.csv", index = False)

# %% [markdown]
# ## Second Fase

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '8839d3f8-4bce-45ac-8059-c9c329c395c1',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    # Use this if you just want to keep it in a dataframe
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df = df.append(df2)


    # Use this if you want to create a csv and append data to it
    #df = pd.json_normalize(data['data'])
    #df['timestamp'] = pd.to_datetime('now')
    #df

    #if not os.path.isfile(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv'):
        #df.to_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv', header='column_names')
    #else:
        #df.to_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv', mode='a', header=False)
        
    #Then to read in the file: df = pd.read_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv')

# %%
import os 
from time import time
from time import sleep

for i in range(3):
    api_runner()
    print('API Runner completed')
    sleep(10) #sleep 60 = 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed

# %%
# Save table as csv

df.to_csv("data/CoinMarketCapDin.csv", index = False)

df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10938
# 1    1027     Ethereum    ETH      ethereum              8610
# 2     825  Tether USDt   USDT        tether             79608
# 3    1839          BNB    BNB           bnb              2113
# 4    5426       Solana    SOL        solana               643
# ..    ...          ...    ...           ...               ...
# 10   5994    Shiba Inu   SHIB     shiba-inu               771
# 11  11419      Toncoin    TON       toncoin               231
# 12   6636     Polkadot    DOT  polkadot-new               721
# 13   1975    Chainlink   LINK     chainlink              1700
# 14   1958         TRON    TRX          tron               957
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# ..                       ...
# ...

# %%
# One thing I noticed was the scientific notation. I like it, but I want to be able to see the numbers in this case

pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
# Now let's look at the coin trends over time

df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h',
                                      'quote.USD.percent_change_7d','quote.USD.percent_change_30d',
                                      'quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#                                quote.USD.percent_change_1h  \
# name
# Bitcoin                                            0.64936
# Ethereum                                          -0.25898
# Tether USDt                                        0.02012
# BNB                                               -0.54978
# Solana                                             0.17288
# ...                                                    ...
# Gametree                                           0.13593
# Triathon                                          -0.86868
# Apu                                               -0.66993
# Toshe                                              1.14461
# Fatih Karagümrük SK Fan Token                     -0.45392
#
#                                quote.USD.percent_change_24h  \
# name
# Bitcoin                                             2.25515
# Ethereum                                            3.66392
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin                        quote.USD.percent_change_1h      0.64936
#                                quote.USD.percent_change_24h     2.25515
#                                quote.USD.percent_change_7d    -11.81635
#                                quote.USD.percent_change_30d    22.90696
#                                quote.USD.percent_change_60d    54.18706
#                                                                  ...
# Fatih Karagümrük SK Fan Token  quote.USD.percent_change_24h    -7.91925
#                                quote.USD.percent_change_7d     -9.56226
#                                quote.USD.percent_change_30d   -22.36157
#                                quote.USD.percent_change_60d   -20.09218
#                                quote.USD.percent_change_90d   -39.92322
# Length: 29766, dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                                               values
# name
# Bitcoin                       quote.USD.percent_change_1h    0.64936
#                               quote.USD.percent_change_24h   2.25515
#                               quote.USD.percent_change_7d  -11.81635
#                               quote.USD.percent_change_30d  22.90696
#                               quote.USD.percent_change_60d  54.18706
# ...                                                              ...
# Fatih Karagümrük SK Fan Token quote.USD.percent_change_24h  -7.91925
#                               quote.USD.percent_change_7d   -9.56226
#                               quote.USD.percent_change_30d -22.36157
#                               quote.USD.percent_change_60d -20.09218
#                               quote.USD.percent_change_90d -39.92322
#
# [29766 rows x 1 columns]

# %%
df5.count()
# Out:
# values    29766
# dtype: int64

# %%
#Because of how it's structured above we need to set an index. I don't want to pass a column as an index for this dataframe
#So I'm going to create a range and pass that as the dataframe. You can make this more dynamic, but I'm just going to hard 
#code it


index = pd.Index(range(29766))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.reset_index()
df6

# If it only has the index and values try doing reset_index like "df5.reset_index()"
# Out:
#                                 name                       level_1    values
# 0                            Bitcoin   quote.USD.percent_change_1h   0.64936
# 1                            Bitcoin  quote.USD.percent_change_24h   2.25515
# 2                            Bitcoin   quote.USD.percent_change_7d -11.81635
# 3                            Bitcoin  quote.USD.percent_change_30d  22.90696
# 4                            Bitcoin  quote.USD.percent_change_60d  54.18706
# ...                              ...                           ...       ...
# 29761  Fatih Karagümrük SK Fan Token  quote.USD.percent_change_24h  -7.91925
# 29762  Fatih Karagümrük SK Fan Token   quote.USD.percent_change_7d  -9.56226
# 29763  Fatih Karagümrük SK Fan Token  quote.USD.percent_change_30d -22.36157
# 29764  Fatih Karagümrük SK Fan Token  quote.USD.percent_change_60d -20.09218
# 29765  Fatih Karagümrük SK Fan Token  quote.USD.percent_change_90d -39.92322
#
# [29766 rows x 3 columns]

# %%
# Change the column name

df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#                                 name                percent_change    values
# 0                            Bitcoin   quote.USD.percent_change_1h   0.64936
# 1                            Bitcoin  quote.USD.percent_change_24h   2.25515
# 2                            Bitcoin   quote.USD.percent_change_7d -11.81635
# 3                            Bitcoin  quote.USD.percent_change_30d  22.90696
# 4                            Bitcoin  quote.USD.percent_change_60d  54.18706
# ...                              ...                           ...       ...
# 29761  Fatih Karagümrük SK Fan Token  quote.USD.percent_change_24h  -7.91925
# 29762  Fatih Karagümrük SK Fan Token   quote.USD.percent_change_7d  -9.56226
# 29763  Fatih Karagümrük SK Fan Token  quote.USD.percent_change_30d -22.36157
# 29764  Fatih Karagümrük SK Fan Token  quote.USD.percent_change_60d -20.09218
# 29765  Fatih Karagümrük SK Fan Token  quote.USD.percent_change_90d -39.92322
#
# [29766 rows x 3 columns]

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d',
                                                       'quote.USD.percent_change_30d','quote.USD.percent_change_60d',
                                                       'quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7
# Out:
#                                 name               percent_change    values
# 0                            Bitcoin  quote.USD.percent_change_1h   0.64936
# 1                            Bitcoin                          24h   2.25515
# 2                            Bitcoin                           7d -11.81635
# 3                            Bitcoin                          30d  22.90696
# 4                            Bitcoin                          60d  54.18706
# ...                              ...                          ...       ...
# 29761  Fatih Karagümrük SK Fan Token                          24h  -7.91925
# 29762  Fatih Karagümrük SK Fan Token                           7d  -9.56226
# 29763  Fatih Karagümrük SK Fan Token                          30d -22.36157
# 29764  Fatih Karagümrük SK Fan Token                          60d -20.09218
# 29765  Fatih Karagümrük SK Fan Token                          90d -39.92322
#
# [29766 rows x 3 columns]
